# %%
import re
from bs4 import BeautifulSoup
import csv
from time import sleep
import requests
import pandas as pd

# %%
def scrape_suburb(url, need_sub):
    headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find the main unordered list with class 'pclist'
    pclist = soup.find('ul', class_='pclist')
    
    if not pclist:
        print("Could not find the pclist")
        return
    
    # Find all list items within the pclist
    postcode_items = pclist.find_all('li', recursive=False)
    print(f"Total postcode items found: {len(postcode_items)}")
    
    # Prepare data for CSV
    data = []
    
    for index, item in enumerate(postcode_items):
        print(f"\nProcessing item {index}:")
        print(item)  # Print the entire item for debugging
        
        postcode_link = item.find('a')
        if postcode_link:
            postcode = postcode_link.text.strip()
            print(f"Postcode found: {postcode}")
            
            suburbs_ul = item.find('ul')
            if suburbs_ul:
                suburbs = suburbs_ul.find_all('li')
                print(f"Suburbs found: {len(suburbs)}")
                
                for suburb in suburbs:
                    suburb_name = suburb.text.strip()
                    data.append([suburb_name, postcode])
                    print(f"Added: {suburb_name}, {postcode}")
            else:
                print("No suburbs found for this postcode")
        else:
            print(f"Warning: No <a> tag found in item {index}")
    
    print(f"\nTotal entries extracted: {len(data)}")
    
    
    df = pd.DataFrame(data, columns=['Suburb', 'Postcode'])
    
    # If a suburb_list is provided, filter the DataFrame
    if need_sub:
        filtered_df = df[df['Suburb'].isin(need_sub)]
        print(f"\nFiltered DataFrame shape: {filtered_df.shape}")
    else:
        filtered_df = df
        print("\nNo filtering applied. Using full DataFrame.")
    
    # Write filtered data to CSV file
    if not filtered_df.empty:
        filtered_df['Postcode'] = filtered_df['Postcode'].astype(int)
        filtered_df = filtered_df[filtered_df['Postcode'] <= 4000]
        filtered_df.to_csv('../data/landing/victoria_suburbs_postcodes.csv', index=False)
        print("Filtered CSV file written successfully")
    else:
        print("No data to write, CSV file not created")
    
    # Print the first few entries for verification
    print("\nFirst 5 entries of the filtered data:")
    print(filtered_df.head())
    
    return filtered_df

# %%
need_sub = ['Albert Park', 'St Kilda', 'Armadale', 'Carlton North', 'Carlton', 'Parkville', 'Collingwood',
            'Abbotsford', 'Docklands', 'East Melbourne', 'St Kilda East', 'Elwood', 'Fitzroy', 
            'Fitzroy North', 'Clifton Hill', 'Flemington', 'Kensington', 'North Melbourne', 'West Melbourne', 
            'Port Melbourne','Prahran','Windsor','Richmond','Burnley','South Melbourne','South Yarra', 'Southbank', 
            'St Kilda', 'Toorak', 'Balwyn','Blackburn','Box Hill','Bulleen','Templestowe','Doncaster', 'Burwood',
            'Ashburton', 'Camberwell','Glen Iris','Canterbury','Surrey Hills','Mont Albert','Chadstone','Oakleigh',
            'Clayton','Doncaster East','Donvale East','Hawthorn','Glen Waverley','Mulgrave','Hawthorn','Kew','Mount Waverley',
            'Nunawading','Mitcham', 'Melbourne',
            'Vermont','Forest Hill','Burwood East','Aspendale','Chelsea','Carrum', 'Bentleigh', 'Brighton', 'Brighton East',
            'Carnegie','Caulfield','Cheltenham','Elsternwick','Hampton','Beaumaris','Malvern','Malvern East','Mentone','Parkdale','Mordialloc'
            ,'Murrumbeena','Hughesdale','Altona','Footscray','Keilor East','Avondale Heights','Melton','Newport','Spotswood', 
            'St Albans','Deer Park','Sunshine','Sydenham','Werribee','Footscray West','Williamstown','Yarraville','Seddon','Broadmeadows','Brunswick','Coburg' 
            ,'Brunswick East','Essendon','Tullamarine','Keilor Moonee Ponds', 'Ascot Vale', 
            'Oak Park','Glenroy','Fawkner','Pascoe Vale','Coburg North','Sunbury','Brunswick West','Bundoora','Greensborough','Hurstbridge',
            'Eltham','Research','Montmorency','Fairfield','Alphington','Heidelberg','Ivanhoe', 
           'Mill Park','Epping Northcote', 'Thomastown','Lalor','Thornbury','Whittlesea','Bayswater','Boronia', 
            'Croydon','Lilydale','Ferntree Gully','Ringwood','Rowville','Wantirna','Berwick','Cranbourne',
            'Dandenong','Dandenong North','Endeavour Hills','Narre Warren','Hampton Park','Noble Park','Pakenham','Springvale',
            'Dromana','Portsea','Frankston' ,'Hastings','Flinders','Mt Eliza','Mornington','Mt Martha','Seaford','Carrum Downs', 'Belmont','Grovedale' 
            'Corio' ,'Geelong','Newcombe' ,'Herne Hill','Geelong West', 'Lara', 'Newtown', 'North Geelong', 'Ballarat', 'Buninyong' ,
            'Sebastopol','Delacombe', 'Wendouree','Alfredton','Bendigo','Flora Hill','East Bendigo','Golden Square','Kangaroo Flat',
            'North Bendigo','Bairnsdale','Benalla','Castlemaine','Echuca','Hamilton','Horsham','Mildura','Moe','Newborough',
            'Morwell','Ocean Grove','Barwon Heads','Portland','Sale','Maffra','Seymour','Shepparton','Swan Hill','Torquay','Traralgon',
            'Wanagaratta','Warragul','Warrnambool','Wodonga']

# %%
url = 'https://postcodes-australia.com/state-postcodes/vic'
scrape_suburb(url, need_sub)
# Out:
# Total postcode items found: 761
#
# Processing item 0:
# <li><a href="https://postcodes-australia.com/postcodes/3000" title="Postcode 3000, Victoria">3000</a>
# <ul>
# <li>Melbourne</li>
# </ul>
# </li>
# Postcode found: 3000
# Suburbs found: 1
# Added: Melbourne, 3000
#
# Processing item 1:
# <li><a href="https://postcodes-australia.com/postcodes/3001" title="Postcode 3001, Victoria">3001</a>
# <ul>
# <li>Melbourne</li>
# </ul>
# </li>
# Postcode found: 3001
# Suburbs found: 1
# Added: Melbourne, 3001
#
# Processing item 2:
# <li><a href="https://postcodes-australia.com/postcodes/3002" title="Postcode 3002, Victoria">3002</a>
# <ul>
# <li>East Melbourne</li>
# </ul>
# </li>
# Postcode found: 3002
# Suburbs found: 1
# Added: East Melbourne, 3002
#
# Processing item 3:
# <li><a href="https://postcodes-australia.com/postcodes/3003" title="Postcode 3003, Victoria">3003</a>
# <ul>
# <li>West Melbourne</li>
# </ul>
# </li>
# Postcode found: 3003
# Suburbs found: 1
# Added: West Melbourne, 3003
#
# Processing item 4:
# <li><a href="https://postcodes-australia.com/postcodes/3004" title="Postcode 3004, Victoria">3004</a>
# <ul>
# <li>Melbourne</li>
# </ul>
# </li>
# Postcode found: 3004
# Suburbs found: 1
# Added: Melbourne, 3004
#
# Processing item 5:
# <li><a href="https://postcodes-australia.com/postcodes/3005" title="Postcode 3005, Victoria">3005</a>
# <ul>
# <li>World Trade Centre</li>
# </ul>
# </li>
# Postcode found: 3005
# Suburbs found: 1
# Added: World Trade Centre, 3005
#
# Processing item 6:
# <li><a href="https://postcodes-australia.com/postcodes/3006" title="Postcode 3006, Victoria">3006</a>
# <ul>
# <li>Southbank</li>
# </ul>
# </li>
# Postcode found: 3006
# Suburbs found: 1
# Added: Southbank, 3006
#
# Processing item 7:
# <li><a href="https://postcodes-australia.com/postcodes/3008" title="Postcode 3008, Victoria">3008</a>
# <ul>
# <li>Docklands</li>
# </ul>
# </li>
# Postcode found: 3008
# Suburbs found: 1
# Added: Docklands, 3008
#
# Processing item 8:
# <li><a href="https://postcodes-australia.com/postcodes/3010" title="Postcode 3010, Victoria">3010</a>
# <ul>
# <li>University Of Melbourne</li>
# </ul>
# </li>
# Postcode found: 3010
# Suburbs found: 1
# Added: University Of Melbourne, 3010
#
# Processing item 9:
# <li><a href="https://postcodes-australia.com/postcodes/3011" title="Postcode 3011, Victoria">3011</a>
# <ul>
# <li>Footscray</li>
# <li>Seddon</li>
# </ul>
# </li>
# Postcode found: 3011
# Suburbs found: 2
# Added: Footscray, 3011
# Added: Seddon, 3011
#
# Processing item 10:
# <li><a href="https://postcodes-australia.com/postcodes/3012" title="Postcode 3012, Victoria">3012</a>
# <ul>
# <li>Brooklyn</li>
# <li>Kingsville</li>
# <li>Maidstone</li>
# <li>Tottenham</li>
# <li>West Footscray</li>
# </ul>
# </li>
# Postcode found: 3012
# Suburbs found: 5
# Added: Brooklyn, 3012
# Added: Kingsville, 3012
# Added: Maidstone, 3012
# Added: Tottenham, 3012
# Added: West Footscray, 3012
#
# Processing item 11:
# <li><a href="https://postcodes-australia.com/postcodes/3013" title="Postcode 3013, Victoria">3013</a>
# <ul>
# <li>Yarraville</li>
# </ul>
# </li>
# Postcode found: 3013
# Suburbs found: 1
# Added: Yarraville, 3013
#
# Processing item 12:
# <li><a href="https://postcodes-australia.com/postcodes/3015" title="Postcode 3015, Victoria">3015</a>
# <ul>
# <li>Newport</li>
# <li>South Kingsville</li>
# <li>Spotswood</li>
# </ul>
# </li>
# Postcode found: 3015
# Suburbs found: 3
# Added: Newport, 3015
# Added: South Kingsville, 3015
# Added: Spotswood, 3015
#
# Processing item 13:
# <li><a href="https://postcodes-australia.com/postcodes/3016" title="Postcode 3016, Victoria">3016</a>
# <ul>
# <li>Williamstown</li>
# <li>Williamstown North</li>
# </ul>
# </li>
# Postcode found: 3016
# Suburbs found: 2
# Added: Williamstown, 3016
# Added: Williamstown North, 3016
#
# Processing item 14:
# <li><a href="https://postcodes-australia.com/postcodes/3018" title="Postcode 3018, Victoria">3018</a>
# <ul>
# <li>Altona</li>
# <li>Seaholme</li>
# </ul>
# </li>
# Postcode found: 3018
# Suburbs found: 2
# Added: Altona, 3018
# Added: Seaholme, 3018
#
# Processing item 15:
# <li><a href="https://postcodes-australia.com/postcodes/3019" title="Postcode 3019, Victoria">3019</a>
# <ul>
# <li>Braybrook</li>
# </ul>
# </li>
# Postcode found: 3019
# Suburbs found: 1
# Added: Braybrook, 3019
#
# Processing item 16:
# <li><a href="https://postcodes-australia.com/postcodes/3020" title="Postcode 3020, Victoria">3020</a>
# <ul>
# <li>Albion</li>
# <li>Sunshine</li>
# <li>Sunshine North</li>
# <li>Sunshine West</li>
# </ul>
# </li>
# Postcode found: 3020
# Suburbs found: 4
# Added: Albion, 3020
# Added: Sunshine, 3020
# Added: Sunshine North, 3020
# Added: Sunshine West, 3020
#
# Processing item 17:
# <li><a href="https://postcodes-australia.com/postcodes/3021" title="Postcode 3021, Victoria">3021</a>
# <ul>
# <li>Albanvale</li>
# <li>Kealba</li>
# <li>Kings Park</li>
# <li>St Albans</li>
# </ul>
# </li>
# Postcode found: 3021
# Suburbs found: 4
# Added: Albanvale, 3021
# Added: Kealba, 3021
# Added: Kings Park, 3021
# Added: St Albans, 3021
#
# Processing item 18:
# <li><a href="https://postcodes-australia.com/postcodes/3022" title="Postcode 3022, Victoria">3022</a>
# <ul>
# <li>Ardeer</li>
# </ul>
# </li>
# Postcode found: 3022
# Suburbs found: 1
# Added: Ardeer, 3022
#
# Processing item 19:
# <li><a href="https://postcodes-australia.com/postcodes/3023" title="Postcode 3023, Victoria">3023</a>
# <ul>
# <li>Burnside</li>
# <li>Cairnlea</li>
# <li>Caroline Springs</li>
# <li>Deer Park</li>
# <li>Ravenhall</li>
# </ul>
# </li>
# Postcode found: 3023
# Suburbs found: 5
# Added: Burnside, 3023
# Added: Cairnlea, 3023
# Added: Caroline Springs, 3023
# Added: Deer Park, 3023
# Added: Ravenhall, 3023
#
# Processing item 20:
# <li><a href="https://postcodes-australia.com/postcodes/3024" title="Postcode 3024, Victoria">3024</a>
# <ul>
# <li>Mambourin</li>
# <li>Mount Cottrell</li>
# <li>Wyndham Vale</li>
# </ul>
# </li>
# Postcode found: 3024
# Suburbs found: 3
# Added: Mambourin, 3024
# Added: Mount Cottrell, 3024
# Added: Wyndham Vale, 3024
#
# Processing item 21:
# <li><a href="https://postcodes-australia.com/postcodes/3025" title="Postcode 3025, Victoria">3025</a>
# <ul>
# <li>Altona North</li>
# </ul>
# </li>
# Postcode found: 3025
# Suburbs found: 1
# Added: Altona North, 3025
#
# Processing item 22:
# <li><a href="https://postcodes-australia.com/postcodes/3026" title="Postcode 3026, Victoria">3026</a>
# <ul>
# <li>Laverton North</li>
# </ul>
# </li>
# Postcode found: 3026
# Suburbs found: 1
# Added: Laverton North, 3026
#
# Processing item 23:
# <li><a href="https://postcodes-australia.com/postcodes/3027" title="Postcode 3027, Victoria">3027</a>
# <ul>
# <li>Laverton Raaf</li>
# <li>Williams Raaf</li>
# </ul>
# </li>
# Postcode found: 3027
# Suburbs found: 2
# Added: Laverton Raaf, 3027
# Added: Williams Raaf, 3027
#
# Processing item 24:
# <li><a href="https://postcodes-australia.com/postcodes/3028" title="Postcode 3028, Victoria">3028</a>
# <ul>
# <li>Altona Meadows</li>
# <li>Laverton</li>
# <li>Seabrook</li>
# </ul>
# </li>
# Postcode found: 3028
# Suburbs found: 3
# Added: Altona Meadows, 3028
# Added: Laverton, 3028
# Added: Seabrook, 3028
#
# Processing item 25:
# <li><a href="https://postcodes-australia.com/postcodes/3029" title="Postcode 3029, Victoria">3029</a>
# <ul>
# <li>Hoppers Crossing</li>
# <li>Tarneit</li>
# <li>Truganina</li>
# </ul>
# </li>
# Postcode found: 3029
# Suburbs found: 3
# Added: Hoppers Crossing, 3029
# Added: Tarneit, 3029
# Added: Truganina, 3029
#
# Processing item 26:
# <li><a href="https://postcodes-australia.com/postcodes/3030" title="Postcode 3030, Victoria">3030</a>
# <ul>
# <li>Chartwell</li>
# <li>Cocoroc</li>
# <li>Derrimut</li>
# <li>Point Cook</li>
# <li>Quandong</li>
# <li>Werribee</li>
# <li>Werribee South</li>
# </ul>
# </li>
# Postcode found: 3030
# Suburbs found: 7
# Added: Chartwell, 3030
# Added: Cocoroc, 3030
# Added: Derrimut, 3030
# Added: Point Cook, 3030
# Added: Quandong, 3030
# Added: Werribee, 3030
# Added: Werribee South, 3030
#
# Processing item 27:
# <li><a href="https://postcodes-australia.com/postcodes/3031" title="Postcode 3031, Victoria">3031</a>
# <ul>
# <li>Flemington</li>
# <li>Kensington</li>
# </ul>
# </li>
# Postcode found: 3031
# Suburbs found: 2
# Added: Flemington, 3031
# Added: Kensington, 3031
#
# Processing item 28:
# <li><a href="https://postcodes-australia.com/postcodes/3032" title="Postcode 3032, Victoria">3032</a>
# <ul>
# <li>Ascot Vale</li>
# <li>Highpoint City</li>
# <li>Maribyrnong</li>
# <li>Travancore</li>
# </ul>
# </li>
# Postcode found: 3032
# Suburbs found: 4
# Added: Ascot Vale, 3032
# Added: Highpoint City, 3032
# Added: Maribyrnong, 3032
# Added: Travancore, 3032
#
# Processing item 29:
# <li><a href="https://postcodes-australia.com/postcodes/3033" title="Postcode 3033, Victoria">3033</a>
# <ul>
# <li>Keilor East</li>
# </ul>
# </li>
# Postcode found: 3033
# Suburbs found: 1
# Added: Keilor East, 3033
#
# Processing item 30:
# <li><a href="https://postcodes-australia.com/postcodes/3034" title="Postcode 3034, Victoria">3034</a>
# <ul>
# <li>Avondale Heights</li>
# </ul>
# </li>
# Postcode found: 3034
# Suburbs found: 1
# Added: Avondale Heights, 3034
#
# Processing item 31:
# <li><a href="https://postcodes-australia.com/postcodes/3036" title="Postcode 3036, Victoria">3036</a>
# <ul>
# <li>Keilor</li>
# <li>Keilor North</li>
# </ul>
# </li>
# Postcode found: 3036
# Suburbs found: 2
# Added: Keilor, 3036
# Added: Keilor North, 3036
#
# Processing item 32:
# <li><a href="https://postcodes-australia.com/postcodes/3037" title="Postcode 3037, Victoria">3037</a>
# <ul>
# <li>Calder Park</li>
# <li>Delahey</li>
# <li>Hillside</li>
# <li>Plumpton</li>
# <li>Sydenham</li>
# <li>Taylors Hill</li>
# </ul>
# </li>
# Postcode found: 3037
# Suburbs found: 6
# Added: Calder Park, 3037
# Added: Delahey, 3037
# Added: Hillside, 3037
# Added: Plumpton, 3037
# Added: Sydenham, 3037
# Added: Taylors Hill, 3037
#
# Processing item 33:
# <li><a href="https://postcodes-australia.com/postcodes/3038" title="Postcode 3038, Victoria">3038</a>
# <ul>
# <li>Keilor Downs</li>
# <li>Keilor Lodge</li>
# <li>Taylors Lakes</li>
# </ul>
# </li>
# Postcode found: 3038
# Suburbs found: 3
# Added: Keilor Downs, 3038
# Added: Keilor Lodge, 3038
# Added: Taylors Lakes, 3038
#
# Processing item 34:
# <li><a href="https://postcodes-australia.com/postcodes/3039" title="Postcode 3039, Victoria">3039</a>
# <ul>
# <li>Moonee Ponds</li>
# </ul>
# </li>
# Postcode found: 3039
# Suburbs found: 1
# Added: Moonee Ponds, 3039
#
# Processing item 35:
# <li><a href="https://postcodes-australia.com/postcodes/3040" title="Postcode 3040, Victoria">3040</a>
# <ul>
# <li>Aberfeldie</li>
# <li>Essendon</li>
# <li>Essendon West</li>
# </ul>
# </li>
# Postcode found: 3040
# Suburbs found: 3
# Added: Aberfeldie, 3040
# Added: Essendon, 3040
# Added: Essendon West, 3040
#
# Processing item 36:
# <li><a href="https://postcodes-australia.com/postcodes/3041" title="Postcode 3041, Victoria">3041</a>
# <ul>
# <li>Essendon North</li>
# <li>Strathmore</li>
# <li>Strathmore Heights</li>
# </ul>
# </li>
# Postcode found: 3041
# Suburbs found: 3
# Added: Essendon North, 3041
# Added: Strathmore, 3041
# Added: Strathmore Heights, 3041
#
# Processing item 37:
# <li><a href="https://postcodes-australia.com/postcodes/3042" title="Postcode 3042, Victoria">3042</a>
# <ul>
# <li>Airport West</li>
# <li>Keilor Park</li>
# <li>Niddrie</li>
# </ul>
# </li>
# Postcode found: 3042
# Suburbs found: 3
# Added: Airport West, 3042
# Added: Keilor Park, 3042
# Added: Niddrie, 3042
#
# Processing item 38:
# <li><a href="https://postcodes-australia.com/postcodes/3043" title="Postcode 3043, Victoria">3043</a>
# <ul>
# <li>Gladstone Park</li>
# <li>Gowanbrae</li>
# <li>Tullamarine</li>
# </ul>
# </li>
# Postcode found: 3043
# Suburbs found: 3
# Added: Gladstone Park, 3043
# Added: Gowanbrae, 3043
# Added: Tullamarine, 3043
#
# Processing item 39:
# <li><a href="https://postcodes-australia.com/postcodes/3044" title="Postcode 3044, Victoria">3044</a>
# <ul>
# <li>Pascoe Vale</li>
# <li>Pascoe Vale South</li>
# </ul>
# </li>
# Postcode found: 3044
# Suburbs found: 2
# Added: Pascoe Vale, 3044
# Added: Pascoe Vale South, 3044
#
# Processing item 40:
# <li><a href="https://postcodes-australia.com/postcodes/3045" title="Postcode 3045, Victoria">3045</a>
# <ul>
# <li>Melbourne Airport</li>
# </ul>
# </li>
# Postcode found: 3045
# Suburbs found: 1
# Added: Melbourne Airport, 3045
#
# Processing item 41:
# <li><a href="https://postcodes-australia.com/postcodes/3046" title="Postcode 3046, Victoria">3046</a>
# <ul>
# <li>Glenroy</li>
# <li>Hadfield</li>
# <li>Oak Park</li>
# </ul>
# </li>
# Postcode found: 3046
# Suburbs found: 3
# Added: Glenroy, 3046
# Added: Hadfield, 3046
# Added: Oak Park, 3046
#
# Processing item 42:
# <li><a href="https://postcodes-australia.com/postcodes/3047" title="Postcode 3047, Victoria">3047</a>
# <ul>
# <li>Broadmeadows</li>
# <li>Dallas</li>
# <li>Jacana</li>
# </ul>
# </li>
# Postcode found: 3047
# Suburbs found: 3
# Added: Broadmeadows, 3047
# Added: Dallas, 3047
# Added: Jacana, 3047
#
# Processing item 43:
# <li><a href="https://postcodes-australia.com/postcodes/3048" title="Postcode 3048, Victoria">3048</a>
# <ul>
# <li>Coolaroo</li>
# <li>Meadow Heights</li>
# </ul>
# </li>
# Postcode found: 3048
# Suburbs found: 2
# Added: Coolaroo, 3048
# Added: Meadow Heights, 3048
#
# Processing item 44:
# <li><a href="https://postcodes-australia.com/postcodes/3049" title="Postcode 3049, Victoria">3049</a>
# <ul>
# <li>Attwood</li>
# <li>Westmeadows</li>
# </ul>
# </li>
# Postcode found: 3049
# Suburbs found: 2
# Added: Attwood, 3049
# Added: Westmeadows, 3049
#
# Processing item 45:
# <li><a href="https://postcodes-australia.com/postcodes/3050" title="Postcode 3050, Victoria">3050</a>
# <ul>
# <li>Royal Melbourne Hospital</li>
# </ul>
# </li>
# Postcode found: 3050
# Suburbs found: 1
# Added: Royal Melbourne Hospital, 3050
#
# Processing item 46:
# <li><a href="https://postcodes-australia.com/postcodes/3051" title="Postcode 3051, Victoria">3051</a>
# <ul>
# <li>North Melbourne</li>
# </ul>
# </li>
# Postcode found: 3051
# Suburbs found: 1
# Added: North Melbourne, 3051
#
# Processing item 47:
# <li><a href="https://postcodes-australia.com/postcodes/3052" title="Postcode 3052, Victoria">3052</a>
# <ul>
# <li>Parkville</li>
# </ul>
# </li>
# Postcode found: 3052
# Suburbs found: 1
# Added: Parkville, 3052
#
# Processing item 48:
# <li><a href="https://postcodes-australia.com/postcodes/3053" title="Postcode 3053, Victoria">3053</a>
# <ul>
# <li>Carlton</li>
# </ul>
# </li>
# Postcode found: 3053
# Suburbs found: 1
# Added: Carlton, 3053
#
# Processing item 49:
# <li><a href="https://postcodes-australia.com/postcodes/3054" title="Postcode 3054, Victoria">3054</a>
# <ul>
# <li>Carlton North</li>
# <li>Princes Hill</li>
# </ul>
# </li>
# Postcode found: 3054
# Suburbs found: 2
# Added: Carlton North, 3054
# Added: Princes Hill, 3054
#
# Processing item 50:
# <li><a href="https://postcodes-australia.com/postcodes/3055" title="Postcode 3055, Victoria">3055</a>
# <ul>
# <li>Brunswick West</li>
# </ul>
# </li>
# Postcode found: 3055
# Suburbs found: 1
# Added: Brunswick West, 3055
#
# Processing item 51:
# <li><a href="https://postcodes-australia.com/postcodes/3056" title="Postcode 3056, Victoria">3056</a>
# <ul>
# <li>Brunswick</li>
# </ul>
# </li>
# Postcode found: 3056
# Suburbs found: 1
# Added: Brunswick, 3056
#
# Processing item 52:
# <li><a href="https://postcodes-australia.com/postcodes/3057" title="Postcode 3057, Victoria">3057</a>
# <ul>
# <li>Brunswick East</li>
# </ul>
# </li>
# Postcode found: 3057
# Suburbs found: 1
# Added: Brunswick East, 3057
#
# Processing item 53:
# <li><a href="https://postcodes-australia.com/postcodes/3058" title="Postcode 3058, Victoria">3058</a>
# <ul>
# <li>Coburg</li>
# <li>Coburg North</li>
# <li>Moreland</li>
# </ul>
# </li>
# Postcode found: 3058
# Suburbs found: 3
# Added: Coburg, 3058
# Added: Coburg North, 3058
# Added: Moreland, 3058
#
# Processing item 54:
# <li><a href="https://postcodes-australia.com/postcodes/3059" title="Postcode 3059, Victoria">3059</a>
# <ul>
# <li>Greenvale</li>
# </ul>
# </li>
# Postcode found: 3059
# Suburbs found: 1
# Added: Greenvale, 3059
#
# Processing item 55:
# <li><a href="https://postcodes-australia.com/postcodes/3060" title="Postcode 3060, Victoria">3060</a>
# <ul>
# <li>Fawkner</li>
# </ul>
# </li>
# Postcode found: 3060
# Suburbs found: 1
# Added: Fawkner, 3060
#
# Processing item 56:
# <li><a href="https://postcodes-australia.com/postcodes/3061" title="Postcode 3061, Victoria">3061</a>
# <ul>
# <li>Campbellfield</li>
# </ul>
# </li>
# Postcode found: 3061
# Suburbs found: 1
# Added: Campbellfield, 3061
#
# Processing item 57:
# <li><a href="https://postcodes-australia.com/postcodes/3062" title="Postcode 3062, Victoria">3062</a>
# <ul>
# <li>Somerton</li>
# </ul>
# </li>
# Postcode found: 3062
# Suburbs found: 1
# Added: Somerton, 3062
#
# Processing item 58:
# <li><a href="https://postcodes-australia.com/postcodes/3063" title="Postcode 3063, Victoria">3063</a>
# <ul>
# <li>Oaklands Junction</li>
# <li>Yuroke</li>
# </ul>
# </li>
# Postcode found: 3063
# Suburbs found: 2
# Added: Oaklands Junction, 3063
# Added: Yuroke, 3063
#
# Processing item 59:
# <li><a href="https://postcodes-australia.com/postcodes/3064" title="Postcode 3064, Victoria">3064</a>
# <ul>
# <li>Craigieburn</li>
# <li>Donnybrook</li>
# <li>Kalkallo</li>
# <li>Mickleham</li>
# <li>Roxburgh Park</li>
# </ul>
# </li>
# Postcode found: 3064
# Suburbs found: 5
# Added: Craigieburn, 3064
# Added: Donnybrook, 3064
# Added: Kalkallo, 3064
# Added: Mickleham, 3064
# Added: Roxburgh Park, 3064
#
# Processing item 60:
# <li><a href="https://postcodes-australia.com/postcodes/3065" title="Postcode 3065, Victoria">3065</a>
# <ul>
# <li>Fitzroy</li>
# </ul>
# </li>
# Postcode found: 3065
# Suburbs found: 1
# Added: Fitzroy, 3065
#
# Processing item 61:
# <li><a href="https://postcodes-australia.com/postcodes/3066" title="Postcode 3066, Victoria">3066</a>
# <ul>
# <li>Collingwood</li>
# </ul>
# </li>
# Postcode found: 3066
# Suburbs found: 1
# Added: Collingwood, 3066
#
# Processing item 62:
# <li><a href="https://postcodes-australia.com/postcodes/3067" title="Postcode 3067, Victoria">3067</a>
# <ul>
# <li>Abbotsford</li>
# </ul>
# </li>
# Postcode found: 3067
# Suburbs found: 1
# Added: Abbotsford, 3067
#
# Processing item 63:
# <li><a href="https://postcodes-australia.com/postcodes/3068" title="Postcode 3068, Victoria">3068</a>
# <ul>
# <li>Clifton Hill</li>
# <li>Fitzroy North</li>
# </ul>
# </li>
# Postcode found: 3068
# Suburbs found: 2
# Added: Clifton Hill, 3068
# Added: Fitzroy North, 3068
#
# Processing item 64:
# <li><a href="https://postcodes-australia.com/postcodes/3070" title="Postcode 3070, Victoria">3070</a>
# <ul>
# <li>Northcote</li>
# </ul>
# </li>
# Postcode found: 3070
# Suburbs found: 1
# Added: Northcote, 3070
#
# Processing item 65:
# <li><a href="https://postcodes-australia.com/postcodes/3071" title="Postcode 3071, Victoria">3071</a>
# <ul>
# <li>Thornbury</li>
# </ul>
# </li>
# Postcode found: 3071
# Suburbs found: 1
# Added: Thornbury, 3071
#
# Processing item 66:
# <li><a href="https://postcodes-australia.com/postcodes/3072" title="Postcode 3072, Victoria">3072</a>
# <ul>
# <li>Preston</li>
# </ul>
# </li>
# Postcode found: 3072
# Suburbs found: 1
# Added: Preston, 3072
#
# Processing item 67:
# <li><a href="https://postcodes-australia.com/postcodes/3073" title="Postcode 3073, Victoria">3073</a>
# <ul>
# <li>Reservoir</li>
# </ul>
# </li>
# Postcode found: 3073
# Suburbs found: 1
# Added: Reservoir, 3073
#
# Processing item 68:
# <li><a href="https://postcodes-australia.com/postcodes/3074" title="Postcode 3074, Victoria">3074</a>
# <ul>
# <li>Thomastown</li>
# </ul>
# </li>
# Postcode found: 3074
# Suburbs found: 1
# Added: Thomastown, 3074
#
# Processing item 69:
# <li><a href="https://postcodes-australia.com/postcodes/3075" title="Postcode 3075, Victoria">3075</a>
# <ul>
# <li>Lalor</li>
# </ul>
# </li>
# Postcode found: 3075
# Suburbs found: 1
# Added: Lalor, 3075
#
# Processing item 70:
# <li><a href="https://postcodes-australia.com/postcodes/3076" title="Postcode 3076, Victoria">3076</a>
# <ul>
# <li>Epping</li>
# <li>Epping Dc</li>
# </ul>
# </li>
# Postcode found: 3076
# Suburbs found: 2
# Added: Epping, 3076
# Added: Epping Dc, 3076
#
# Processing item 71:
# <li><a href="https://postcodes-australia.com/postcodes/3078" title="Postcode 3078, Victoria">3078</a>
# <ul>
# <li>Alphington</li>
# <li>Fairfield</li>
# </ul>
# </li>
# Postcode found: 3078
# Suburbs found: 2
# Added: Alphington, 3078
# Added: Fairfield, 3078
#
# Processing item 72:
# <li><a href="https://postcodes-australia.com/postcodes/3079" title="Postcode 3079, Victoria">3079</a>
# <ul>
# <li>Ivanhoe</li>
# <li>Ivanhoe East</li>
# </ul>
# </li>
# Postcode found: 3079
# Suburbs found: 2
# Added: Ivanhoe, 3079
# Added: Ivanhoe East, 3079
#
# Processing item 73:
# <li><a href="https://postcodes-australia.com/postcodes/3081" title="Postcode 3081, Victoria">3081</a>
# <ul>
# <li>Bellfield</li>
# <li>Heidelberg Heights</li>
# <li>Heidelberg Rgh</li>
# <li>Heidelberg West</li>
# </ul>
# </li>
# Postcode found: 3081
# Suburbs found: 4
# Added: Bellfield, 3081
# Added: Heidelberg Heights, 3081
# Added: Heidelberg Rgh, 3081
# Added: Heidelberg West, 3081
#
# Processing item 74:
# <li><a href="https://postcodes-australia.com/postcodes/3082" title="Postcode 3082, Victoria">3082</a>
# <ul>
# <li>Mill Park</li>
# </ul>
# </li>
# Postcode found: 3082
# Suburbs found: 1
# Added: Mill Park, 3082
#
# Processing item 75:
# <li><a href="https://postcodes-australia.com/postcodes/3083" title="Postcode 3083, Victoria">3083</a>
# <ul>
# <li>Bundoora</li>
# <li>Kingsbury</li>
# <li>La Trobe University</li>
# </ul>
# </li>
# Postcode found: 3083
# Suburbs found: 3
# Added: Bundoora, 3083
# Added: Kingsbury, 3083
# Added: La Trobe University, 3083
#
# Processing item 76:
# <li><a href="https://postcodes-australia.com/postcodes/3084" title="Postcode 3084, Victoria">3084</a>
# <ul>
# <li>Eaglemont</li>
# <li>Heidelberg</li>
# <li>Rosanna</li>
# <li>Viewbank</li>
# </ul>
# </li>
# Postcode found: 3084
# Suburbs found: 4
# Added: Eaglemont, 3084
# Added: Heidelberg, 3084
# Added: Rosanna, 3084
# Added: Viewbank, 3084
#
# Processing item 77:
# <li><a href="https://postcodes-australia.com/postcodes/3085" title="Postcode 3085, Victoria">3085</a>
# <ul>
# <li>Macleod</li>
# <li>Yallambie</li>
# </ul>
# </li>
# Postcode found: 3085
# Suburbs found: 2
# Added: Macleod, 3085
# Added: Yallambie, 3085
#
# Processing item 78:
# <li><a href="https://postcodes-australia.com/postcodes/3086" title="Postcode 3086, Victoria">3086</a>
# <ul>
# <li>La Trobe University</li>
# </ul>
# </li>
# Postcode found: 3086
# Suburbs found: 1
# Added: La Trobe University, 3086
#
# Processing item 79:
# <li><a href="https://postcodes-australia.com/postcodes/3087" title="Postcode 3087, Victoria">3087</a>
# <ul>
# <li>Watsonia</li>
# <li>Watsonia North</li>
# </ul>
# </li>
# Postcode found: 3087
# Suburbs found: 2
# Added: Watsonia, 3087
# Added: Watsonia North, 3087
#
# Processing item 80:
# <li><a href="https://postcodes-australia.com/postcodes/3088" title="Postcode 3088, Victoria">3088</a>
# <ul>
# <li>Briar Hill</li>
# <li>Greensborough</li>
# <li>Saint Helena</li>
# </ul>
# </li>
# Postcode found: 3088
# Suburbs found: 3
# Added: Briar Hill, 3088
# Added: Greensborough, 3088
# Added: Saint Helena, 3088
#
# Processing item 81:
# <li><a href="https://postcodes-australia.com/postcodes/3089" title="Postcode 3089, Victoria">3089</a>
# <ul>
# <li>Diamond Creek</li>
# </ul>
# </li>
# Postcode found: 3089
# Suburbs found: 1
# Added: Diamond Creek, 3089
#
# Processing item 82:
# <li><a href="https://postcodes-australia.com/postcodes/3090" title="Postcode 3090, Victoria">3090</a>
# <ul>
# <li>Plenty</li>
# </ul>
# </li>
# Postcode found: 3090
# Suburbs found: 1
# Added: Plenty, 3090
#
# Processing item 83:
# <li><a href="https://postcodes-australia.com/postcodes/3091" title="Postcode 3091, Victoria">3091</a>
# <ul>
# <li>Yarrambat</li>
# </ul>
# </li>
# Postcode found: 3091
# Suburbs found: 1
# Added: Yarrambat, 3091
#
# Processing item 84:
# <li><a href="https://postcodes-australia.com/postcodes/3093" title="Postcode 3093, Victoria">3093</a>
# <ul>
# <li>Lower Plenty</li>
# </ul>
# </li>
# Postcode found: 3093
# Suburbs found: 1
# Added: Lower Plenty, 3093
#
# Processing item 85:
# <li><a href="https://postcodes-australia.com/postcodes/3094" title="Postcode 3094, Victoria">3094</a>
# <ul>
# <li>Montmorency</li>
# </ul>
# </li>
# Postcode found: 3094
# Suburbs found: 1
# Added: Montmorency, 3094
#
# Processing item 86:
# <li><a href="https://postcodes-australia.com/postcodes/3095" title="Postcode 3095, Victoria">3095</a>
# <ul>
# <li>Eltham</li>
# <li>Eltham North</li>
# <li>Research</li>
# </ul>
# </li>
# Postcode found: 3095
# Suburbs found: 3
# Added: Eltham, 3095
# Added: Eltham North, 3095
# Added: Research, 3095
#
# Processing item 87:
# <li><a href="https://postcodes-australia.com/postcodes/3096" title="Postcode 3096, Victoria">3096</a>
# <ul>
# <li>Wattle Glen</li>
# </ul>
# </li>
# Postcode found: 3096
# Suburbs found: 1
# Added: Wattle Glen, 3096
#
# Processing item 88:
# <li><a href="https://postcodes-australia.com/postcodes/3097" title="Postcode 3097, Victoria">3097</a>
# <ul>
# <li>Bend Of Islands</li>
# <li>Kangaroo Ground</li>
# <li>Watsons Creek</li>
# </ul>
# </li>
# Postcode found: 3097
# Suburbs found: 3
# Added: Bend Of Islands, 3097
# Added: Kangaroo Ground, 3097
# Added: Watsons Creek, 3097
#
# Processing item 89:
# <li><a href="https://postcodes-australia.com/postcodes/3099" title="Postcode 3099, Victoria">3099</a>
# <ul>
# <li>Arthurs Creek</li>
# <li>Cottles Bridge</li>
# <li>Hurstbridge</li>
# <li>Nutfield</li>
# <li>Strathewen</li>
# </ul>
# </li>
# Postcode found: 3099
# Suburbs found: 5
# Added: Arthurs Creek, 3099
# Added: Cottles Bridge, 3099
# Added: Hurstbridge, 3099
# Added: Nutfield, 3099
# Added: Strathewen, 3099
#
# Processing item 90:
# <li><a href="https://postcodes-australia.com/postcodes/3101" title="Postcode 3101, Victoria">3101</a>
# <ul>
# <li>Kew</li>
# </ul>
# </li>
# Postcode found: 3101
# Suburbs found: 1
# Added: Kew, 3101
#
# Processing item 91:
# <li><a href="https://postcodes-australia.com/postcodes/3102" title="Postcode 3102, Victoria">3102</a>
# <ul>
# <li>Kew East</li>
# </ul>
# </li>
# Postcode found: 3102
# Suburbs found: 1
# Added: Kew East, 3102
#
# Processing item 92:
# <li><a href="https://postcodes-australia.com/postcodes/3103" title="Postcode 3103, Victoria">3103</a>
# <ul>
# <li>Balwyn</li>
# </ul>
# </li>
# Postcode found: 3103
# Suburbs found: 1
# Added: Balwyn, 3103
#
# Processing item 93:
# <li><a href="https://postcodes-australia.com/postcodes/3104" title="Postcode 3104, Victoria">3104</a>
# <ul>
# <li>Balwyn North</li>
# </ul>
# </li>
# Postcode found: 3104
# Suburbs found: 1
# Added: Balwyn North, 3104
#
# Processing item 94:
# <li><a href="https://postcodes-australia.com/postcodes/3105" title="Postcode 3105, Victoria">3105</a>
# <ul>
# <li>Bulleen</li>
# </ul>
# </li>
# Postcode found: 3105
# Suburbs found: 1
# Added: Bulleen, 3105
#
# Processing item 95:
# <li><a href="https://postcodes-australia.com/postcodes/3106" title="Postcode 3106, Victoria">3106</a>
# <ul>
# <li>Templestowe</li>
# </ul>
# </li>
# Postcode found: 3106
# Suburbs found: 1
# Added: Templestowe, 3106
#
# Processing item 96:
# <li><a href="https://postcodes-australia.com/postcodes/3107" title="Postcode 3107, Victoria">3107</a>
# <ul>
# <li>Templestowe Lower</li>
# </ul>
# </li>
# Postcode found: 3107
# Suburbs found: 1
# Added: Templestowe Lower, 3107
#
# Processing item 97:
# <li><a href="https://postcodes-australia.com/postcodes/3108" title="Postcode 3108, Victoria">3108</a>
# <ul>
# <li>Doncaster</li>
# </ul>
# </li>
# Postcode found: 3108
# Suburbs found: 1
# Added: Doncaster, 3108
#
# Processing item 98:
# <li><a href="https://postcodes-australia.com/postcodes/3109" title="Postcode 3109, Victoria">3109</a>
# <ul>
# <li>Doncaster East</li>
# </ul>
# </li>
# Postcode found: 3109
# Suburbs found: 1
# Added: Doncaster East, 3109
#
# Processing item 99:
# <li><a href="https://postcodes-australia.com/postcodes/3110" title="Postcode 3110, Victoria">3110</a>
# <ul>
# <li>Administrative Postcode Only</li>
# </ul>
# </li>
# Postcode found: 3110
# Suburbs found: 1
# Added: Administrative Postcode Only, 3110
#
# Processing item 100:
# <li><a href="https://postcodes-australia.com/postcodes/3111" title="Postcode 3111, Victoria">3111</a>
# <ul>
# <li>Donvale</li>
# </ul>
# </li>
# Postcode found: 3111
# Suburbs found: 1
# Added: Donvale, 3111
#
# Processing item 101:
# <li><a href="https://postcodes-australia.com/postcodes/3113" title="Postcode 3113, Victoria">3113</a>
# <ul>
# <li>North Warrandyte</li>
# <li>Warrandyte</li>
# </ul>
# </li>
# Postcode found: 3113
# Suburbs found: 2
# Added: North Warrandyte, 3113
# Added: Warrandyte, 3113
#
# Processing item 102:
# <li><a href="https://postcodes-australia.com/postcodes/3114" title="Postcode 3114, Victoria">3114</a>
# <ul>
# <li>Park Orchards</li>
# </ul>
# </li>
# Postcode found: 3114
# Suburbs found: 1
# Added: Park Orchards, 3114
#
# Processing item 103:
# <li><a href="https://postcodes-australia.com/postcodes/3115" title="Postcode 3115, Victoria">3115</a>
# <ul>
# <li>Wonga Park</li>
# </ul>
# </li>
# Postcode found: 3115
# Suburbs found: 1
# Added: Wonga Park, 3115
#
# Processing item 104:
# <li><a href="https://postcodes-australia.com/postcodes/3116" title="Postcode 3116, Victoria">3116</a>
# <ul>
# <li>Chirnside Park</li>
# </ul>
# </li>
# Postcode found: 3116
# Suburbs found: 1
# Added: Chirnside Park, 3116
#
# Processing item 105:
# <li><a href="https://postcodes-australia.com/postcodes/3121" title="Postcode 3121, Victoria">3121</a>
# <ul>
# <li>Burnley</li>
# <li>Cremorne</li>
# <li>Richmond</li>
# </ul>
# </li>
# Postcode found: 3121
# Suburbs found: 3
# Added: Burnley, 3121
# Added: Cremorne, 3121
# Added: Richmond, 3121
#
# Processing item 106:
# <li><a href="https://postcodes-australia.com/postcodes/3122" title="Postcode 3122, Victoria">3122</a>
# <ul>
# <li>Hawthorn</li>
# </ul>
# </li>
# Postcode found: 3122
# Suburbs found: 1
# Added: Hawthorn, 3122
#
# Processing item 107:
# <li><a href="https://postcodes-australia.com/postcodes/3123" title="Postcode 3123, Victoria">3123</a>
# <ul>
# <li>Hawthorn East</li>
# </ul>
# </li>
# Postcode found: 3123
# Suburbs found: 1
# Added: Hawthorn East, 3123
#
# Processing item 108:
# <li><a href="https://postcodes-australia.com/postcodes/3124" title="Postcode 3124, Victoria">3124</a>
# <ul>
# <li>Camberwell</li>
# </ul>
# </li>
# Postcode found: 3124
# Suburbs found: 1
# Added: Camberwell, 3124
#
# Processing item 109:
# <li><a href="https://postcodes-australia.com/postcodes/3125" title="Postcode 3125, Victoria">3125</a>
# <ul>
# <li>Burwood</li>
# </ul>
# </li>
# Postcode found: 3125
# Suburbs found: 1
# Added: Burwood, 3125
#
# Processing item 110:
# <li><a href="https://postcodes-australia.com/postcodes/3126" title="Postcode 3126, Victoria">3126</a>
# <ul>
# <li>Canterbury</li>
# </ul>
# </li>
# Postcode found: 3126
# Suburbs found: 1
# Added: Canterbury, 3126
#
# Processing item 111:
# <li><a href="https://postcodes-australia.com/postcodes/3127" title="Postcode 3127, Victoria">3127</a>
# <ul>
# <li>Mont Albert</li>
# <li>Surrey Hills</li>
# </ul>
# </li>
# Postcode found: 3127
# Suburbs found: 2
# Added: Mont Albert, 3127
# Added: Surrey Hills, 3127
#
# Processing item 112:
# <li><a href="https://postcodes-australia.com/postcodes/3128" title="Postcode 3128, Victoria">3128</a>
# <ul>
# <li>Box Hill</li>
# <li>Box Hill Central</li>
# <li>Box Hill South</li>
# </ul>
# </li>
# Postcode found: 3128
# Suburbs found: 3
# Added: Box Hill, 3128
# Added: Box Hill Central, 3128
# Added: Box Hill South, 3128
#
# Processing item 113:
# <li><a href="https://postcodes-australia.com/postcodes/3129" title="Postcode 3129, Victoria">3129</a>
# <ul>
# <li>Box Hill North</li>
# <li>Mont Albert North</li>
# </ul>
# </li>
# Postcode found: 3129
# Suburbs found: 2
# Added: Box Hill North, 3129
# Added: Mont Albert North, 3129
#
# Processing item 114:
# <li><a href="https://postcodes-australia.com/postcodes/3130" title="Postcode 3130, Victoria">3130</a>
# <ul>
# <li>Blackburn</li>
# <li>Blackburn North</li>
# <li>Blackburn South</li>
# </ul>
# </li>
# Postcode found: 3130
# Suburbs found: 3
# Added: Blackburn, 3130
# Added: Blackburn North, 3130
# Added: Blackburn South, 3130
#
# Processing item 115:
# <li><a href="https://postcodes-australia.com/postcodes/3131" title="Postcode 3131, Victoria">3131</a>
# <ul>
# <li>Forest Hill</li>
# <li>Nunawading</li>
# </ul>
# </li>
# Postcode found: 3131
# Suburbs found: 2
# Added: Forest Hill, 3131
# Added: Nunawading, 3131
#
# Processing item 116:
# <li><a href="https://postcodes-australia.com/postcodes/3132" title="Postcode 3132, Victoria">3132</a>
# <ul>
# <li>Mitcham</li>
# </ul>
# </li>
# Postcode found: 3132
# Suburbs found: 1
# Added: Mitcham, 3132
#
# Processing item 117:
# <li><a href="https://postcodes-australia.com/postcodes/3133" title="Postcode 3133, Victoria">3133</a>
# <ul>
# <li>Vermont</li>
# <li>Vermont South</li>
# </ul>
# </li>
# Postcode found: 3133
# Suburbs found: 2
# Added: Vermont, 3133
# Added: Vermont South, 3133
#
# Processing item 118:
# <li><a href="https://postcodes-australia.com/postcodes/3134" title="Postcode 3134, Victoria">3134</a>
# <ul>
# <li>Ringwood</li>
# <li>Ringwood North</li>
# <li>Warrandyte South</li>
# <li>Warranwood</li>
# </ul>
# </li>
# Postcode found: 3134
# Suburbs found: 4
# Added: Ringwood, 3134
# Added: Ringwood North, 3134
# Added: Warrandyte South, 3134
# Added: Warranwood, 3134
#
# Processing item 119:
# <li><a href="https://postcodes-australia.com/postcodes/3135" title="Postcode 3135, Victoria">3135</a>
# <ul>
# <li>Heathmont</li>
# <li>Ringwood East</li>
# </ul>
# </li>
# Postcode found: 3135
# Suburbs found: 2
# Added: Heathmont, 3135
# Added: Ringwood East, 3135
#
# Processing item 120:
# <li><a href="https://postcodes-australia.com/postcodes/3136" title="Postcode 3136, Victoria">3136</a>
# <ul>
# <li>Croydon</li>
# <li>Croydon Hills</li>
# <li>Croydon North</li>
# <li>Croydon South</li>
# </ul>
# </li>
# Postcode found: 3136
# Suburbs found: 4
# Added: Croydon, 3136
# Added: Croydon Hills, 3136
# Added: Croydon North, 3136
# Added: Croydon South, 3136
#
# Processing item 121:
# <li><a href="https://postcodes-australia.com/postcodes/3137" title="Postcode 3137, Victoria">3137</a>
# <ul>
# <li>Kilsyth</li>
# <li>Kilsyth South</li>
# </ul>
# </li>
# Postcode found: 3137
# Suburbs found: 2
# Added: Kilsyth, 3137
# Added: Kilsyth South, 3137
#
# Processing item 122:
# <li><a href="https://postcodes-australia.com/postcodes/3138" title="Postcode 3138, Victoria">3138</a>
# <ul>
# <li>Mooroolbark</li>
# </ul>
# </li>
# Postcode found: 3138
# Suburbs found: 1
# Added: Mooroolbark, 3138
#
# Processing item 123:
# <li><a href="https://postcodes-australia.com/postcodes/3139" title="Postcode 3139, Victoria">3139</a>
# <ul>
# <li>Beenak</li>
# <li>Don Valley</li>
# <li>Hoddles Creek</li>
# <li>Launching Place</li>
# <li>Seville</li>
# <li>Seville East</li>
# <li>Wandin East</li>
# <li>Wandin North</li>
# <li>Woori Yallock</li>
# <li>Yellingbo</li>
# </ul>
# </li>
# Postcode found: 3139
# Suburbs found: 10
# Added: Beenak, 3139
# Added: Don Valley, 3139
# Added: Hoddles Creek, 3139
# Added: Launching Place, 3139
# Added: Seville, 3139
# Added: Seville East, 3139
# Added: Wandin East, 3139
# Added: Wandin North, 3139
# Added: Woori Yallock, 3139
# Added: Yellingbo, 3139
#
# Processing item 124:
# <li><a href="https://postcodes-australia.com/postcodes/3140" title="Postcode 3140, Victoria">3140</a>
# <ul>
# <li>Lilydale</li>
# </ul>
# </li>
# Postcode found: 3140
# Suburbs found: 1
# Added: Lilydale, 3140
#
# Processing item 125:
# <li><a href="https://postcodes-australia.com/postcodes/3141" title="Postcode 3141, Victoria">3141</a>
# <ul>
# <li>South Yarra</li>
# </ul>
# </li>
# Postcode found: 3141
# Suburbs found: 1
# Added: South Yarra, 3141
#
# Processing item 126:
# <li><a href="https://postcodes-australia.com/postcodes/3142" title="Postcode 3142, Victoria">3142</a>
# <ul>
# <li>Toorak</li>
# </ul>
# </li>
# Postcode found: 3142
# Suburbs found: 1
# Added: Toorak, 3142
#
# Processing item 127:
# <li><a href="https://postcodes-australia.com/postcodes/3143" title="Postcode 3143, Victoria">3143</a>
# <ul>
# <li>Armadale</li>
# </ul>
# </li>
# Postcode found: 3143
# Suburbs found: 1
# Added: Armadale, 3143
#
# Processing item 128:
# <li><a href="https://postcodes-australia.com/postcodes/3144" title="Postcode 3144, Victoria">3144</a>
# <ul>
# <li>Kooyong</li>
# <li>Malvern</li>
# </ul>
# </li>
# Postcode found: 3144
# Suburbs found: 2
# Added: Kooyong, 3144
# Added: Malvern, 3144
#
# Processing item 129:
# <li><a href="https://postcodes-australia.com/postcodes/3145" title="Postcode 3145, Victoria">3145</a>
# <ul>
# <li>Caulfield East</li>
# <li>Malvern East</li>
# </ul>
# </li>
# Postcode found: 3145
# Suburbs found: 2
# Added: Caulfield East, 3145
# Added: Malvern East, 3145
#
# Processing item 130:
# <li><a href="https://postcodes-australia.com/postcodes/3146" title="Postcode 3146, Victoria">3146</a>
# <ul>
# <li>Glen Iris</li>
# </ul>
# </li>
# Postcode found: 3146
# Suburbs found: 1
# Added: Glen Iris, 3146
#
# Processing item 131:
# <li><a href="https://postcodes-australia.com/postcodes/3147" title="Postcode 3147, Victoria">3147</a>
# <ul>
# <li>Ashburton</li>
# <li>Ashwood</li>
# </ul>
# </li>
# Postcode found: 3147
# Suburbs found: 2
# Added: Ashburton, 3147
# Added: Ashwood, 3147
#
# Processing item 132:
# <li><a href="https://postcodes-australia.com/postcodes/3148" title="Postcode 3148, Victoria">3148</a>
# <ul>
# <li>Chadstone</li>
# <li>Chadstone Centre</li>
# </ul>
# </li>
# Postcode found: 3148
# Suburbs found: 2
# Added: Chadstone, 3148
# Added: Chadstone Centre, 3148
#
# Processing item 133:
# <li><a href="https://postcodes-australia.com/postcodes/3149" title="Postcode 3149, Victoria">3149</a>
# <ul>
# <li>Mount Waverley</li>
# </ul>
# </li>
# Postcode found: 3149
# Suburbs found: 1
# Added: Mount Waverley, 3149
#
# Processing item 134:
# <li><a href="https://postcodes-australia.com/postcodes/3150" title="Postcode 3150, Victoria">3150</a>
# <ul>
# <li>Glen Waverley</li>
# <li>Wheelers Hill</li>
# </ul>
# </li>
# Postcode found: 3150
# Suburbs found: 2
# Added: Glen Waverley, 3150
# Added: Wheelers Hill, 3150
#
# Processing item 135:
# <li><a href="https://postcodes-australia.com/postcodes/3151" title="Postcode 3151, Victoria">3151</a>
# <ul>
# <li>Burwood East</li>
# </ul>
# </li>
# Postcode found: 3151
# Suburbs found: 1
# Added: Burwood East, 3151
#
# Processing item 136:
# <li><a href="https://postcodes-australia.com/postcodes/3152" title="Postcode 3152, Victoria">3152</a>
# <ul>
# <li>Knox City Centre</li>
# <li>Wantirna</li>
# <li>Wantirna South</li>
# </ul>
# </li>
# Postcode found: 3152
# Suburbs found: 3
# Added: Knox City Centre, 3152
# Added: Wantirna, 3152
# Added: Wantirna South, 3152
#
# Processing item 137:
# <li><a href="https://postcodes-australia.com/postcodes/3153" title="Postcode 3153, Victoria">3153</a>
# <ul>
# <li>Bayswater</li>
# <li>Bayswater North</li>
# </ul>
# </li>
# Postcode found: 3153
# Suburbs found: 2
# Added: Bayswater, 3153
# Added: Bayswater North, 3153
#
# Processing item 138:
# <li><a href="https://postcodes-australia.com/postcodes/3154" title="Postcode 3154, Victoria">3154</a>
# <ul>
# <li>The Basin</li>
# </ul>
# </li>
# Postcode found: 3154
# Suburbs found: 1
# Added: The Basin, 3154
#
# Processing item 139:
# <li><a href="https://postcodes-australia.com/postcodes/3155" title="Postcode 3155, Victoria">3155</a>
# <ul>
# <li>Boronia</li>
# </ul>
# </li>
# Postcode found: 3155
# Suburbs found: 1
# Added: Boronia, 3155
#
# Processing item 140:
# <li><a href="https://postcodes-australia.com/postcodes/3156" title="Postcode 3156, Victoria">3156</a>
# <ul>
# <li>Ferntree Gully</li>
# <li>Lysterfield</li>
# <li>Lysterfield South</li>
# <li>Upper Ferntree Gully</li>
# </ul>
# </li>
# Postcode found: 3156
# Suburbs found: 4
# Added: Ferntree Gully, 3156
# Added: Lysterfield, 3156
# Added: Lysterfield South, 3156
# Added: Upper Ferntree Gully, 3156
#
# Processing item 141:
# <li><a href="https://postcodes-australia.com/postcodes/3158" title="Postcode 3158, Victoria">3158</a>
# <ul>
# <li>Upwey</li>
# </ul>
# </li>
# Postcode found: 3158
# Suburbs found: 1
# Added: Upwey, 3158
#
# Processing item 142:
# <li><a href="https://postcodes-australia.com/postcodes/3159" title="Postcode 3159, Victoria">3159</a>
# <ul>
# <li>Menzies Creek</li>
# <li>Selby</li>
# </ul>
# </li>
# Postcode found: 3159
# Suburbs found: 2
# Added: Menzies Creek, 3159
# Added: Selby, 3159
#
# Processing item 143:
# <li><a href="https://postcodes-australia.com/postcodes/3160" title="Postcode 3160, Victoria">3160</a>
# <ul>
# <li>Belgrave</li>
# <li>Belgrave Heights</li>
# <li>Belgrave South</li>
# <li>Tecoma</li>
# </ul>
# </li>
# Postcode found: 3160
# Suburbs found: 4
# Added: Belgrave, 3160
# Added: Belgrave Heights, 3160
# Added: Belgrave South, 3160
# Added: Tecoma, 3160
#
# Processing item 144:
# <li><a href="https://postcodes-australia.com/postcodes/3161" title="Postcode 3161, Victoria">3161</a>
# <ul>
# <li>Caulfield North</li>
# </ul>
# </li>
# Postcode found: 3161
# Suburbs found: 1
# Added: Caulfield North, 3161
#
# Processing item 145:
# <li><a href="https://postcodes-australia.com/postcodes/3162" title="Postcode 3162, Victoria">3162</a>
# <ul>
# <li>Caulfield</li>
# <li>Caulfield South</li>
# </ul>
# </li>
# Postcode found: 3162
# Suburbs found: 2
# Added: Caulfield, 3162
# Added: Caulfield South, 3162
#
# Processing item 146:
# <li><a href="https://postcodes-australia.com/postcodes/3163" title="Postcode 3163, Victoria">3163</a>
# <ul>
# <li>Carnegie</li>
# <li>Glen Huntly</li>
# <li>Murrumbeena</li>
# </ul>
# </li>
# Postcode found: 3163
# Suburbs found: 3
# Added: Carnegie, 3163
# Added: Glen Huntly, 3163
# Added: Murrumbeena, 3163
#
# Processing item 147:
# <li><a href="https://postcodes-australia.com/postcodes/3164" title="Postcode 3164, Victoria">3164</a>
# <ul>
# <li>Dandenong South</li>
# </ul>
# </li>
# Postcode found: 3164
# Suburbs found: 1
# Added: Dandenong South, 3164
#
# Processing item 148:
# <li><a href="https://postcodes-australia.com/postcodes/3165" title="Postcode 3165, Victoria">3165</a>
# <ul>
# <li>Bentleigh East</li>
# </ul>
# </li>
# Postcode found: 3165
# Suburbs found: 1
# Added: Bentleigh East, 3165
#
# Processing item 149:
# <li><a href="https://postcodes-australia.com/postcodes/3166" title="Postcode 3166, Victoria">3166</a>
# <ul>
# <li>Hughesdale</li>
# <li>Huntingdale</li>
# <li>Oakleigh</li>
# <li>Oakleigh East</li>
# </ul>
# </li>
# Postcode found: 3166
# Suburbs found: 4
# Added: Hughesdale, 3166
# Added: Huntingdale, 3166
# Added: Oakleigh, 3166
# Added: Oakleigh East, 3166
#
# Processing item 150:
# <li><a href="https://postcodes-australia.com/postcodes/3167" title="Postcode 3167, Victoria">3167</a>
# <ul>
# <li>Oakleigh South</li>
# </ul>
# </li>
# Postcode found: 3167
# Suburbs found: 1
# Added: Oakleigh South, 3167
#
# Processing item 151:
# <li><a href="https://postcodes-australia.com/postcodes/3168" title="Postcode 3168, Victoria">3168</a>
# <ul>
# <li>Clayton</li>
# <li>Notting Hill</li>
# </ul>
# </li>
# Postcode found: 3168
# Suburbs found: 2
# Added: Clayton, 3168
# Added: Notting Hill, 3168
#
# Processing item 152:
# <li><a href="https://postcodes-australia.com/postcodes/3169" title="Postcode 3169, Victoria">3169</a>
# <ul>
# <li>Clarinda</li>
# <li>Clayton South</li>
# </ul>
# </li>
# Postcode found: 3169
# Suburbs found: 2
# Added: Clarinda, 3169
# Added: Clayton South, 3169
#
# Processing item 153:
# <li><a href="https://postcodes-australia.com/postcodes/3170" title="Postcode 3170, Victoria">3170</a>
# <ul>
# <li>Mulgrave</li>
# </ul>
# </li>
# Postcode found: 3170
# Suburbs found: 1
# Added: Mulgrave, 3170
#
# Processing item 154:
# <li><a href="https://postcodes-australia.com/postcodes/3171" title="Postcode 3171, Victoria">3171</a>
# <ul>
# <li>Springvale</li>
# </ul>
# </li>
# Postcode found: 3171
# Suburbs found: 1
# Added: Springvale, 3171
#
# Processing item 155:
# <li><a href="https://postcodes-australia.com/postcodes/3172" title="Postcode 3172, Victoria">3172</a>
# <ul>
# <li>Dingley Village</li>
# <li>Springvale South</li>
# </ul>
# </li>
# Postcode found: 3172
# Suburbs found: 2
# Added: Dingley Village, 3172
# Added: Springvale South, 3172
#
# Processing item 156:
# <li><a href="https://postcodes-australia.com/postcodes/3173" title="Postcode 3173, Victoria">3173</a>
# <ul>
# <li>Keysborough</li>
# </ul>
# </li>
# Postcode found: 3173
# Suburbs found: 1
# Added: Keysborough, 3173
#
# Processing item 157:
# <li><a href="https://postcodes-australia.com/postcodes/3174" title="Postcode 3174, Victoria">3174</a>
# <ul>
# <li>Noble Park</li>
# <li>Noble Park North</li>
# </ul>
# </li>
# Postcode found: 3174
# Suburbs found: 2
# Added: Noble Park, 3174
# Added: Noble Park North, 3174
#
# Processing item 158:
# <li><a href="https://postcodes-australia.com/postcodes/3175" title="Postcode 3175, Victoria">3175</a>
# <ul>
# <li>Bangholme</li>
# <li>Dandenong</li>
# <li>Dandenong North</li>
# <li>Dandenong South</li>
# </ul>
# </li>
# Postcode found: 3175
# Suburbs found: 4
# Added: Bangholme, 3175
# Added: Dandenong, 3175
# Added: Dandenong North, 3175
# Added: Dandenong South, 3175
#
# Processing item 159:
# <li><a href="https://postcodes-australia.com/postcodes/3176" title="Postcode 3176, Victoria">3176</a>
# <ul>
# <li>Administrative Postcode Only</li>
# </ul>
# </li>
# Postcode found: 3176
# Suburbs found: 1
# Added: Administrative Postcode Only, 3176
#
# Processing item 160:
# <li><a href="https://postcodes-australia.com/postcodes/3177" title="Postcode 3177, Victoria">3177</a>
# <ul>
# <li>Doveton</li>
# <li>Eumemmerring</li>
# </ul>
# </li>
# Postcode found: 3177
# Suburbs found: 2
# Added: Doveton, 3177
# Added: Eumemmerring, 3177
#
# Processing item 161:
# <li><a href="https://postcodes-australia.com/postcodes/3178" title="Postcode 3178, Victoria">3178</a>
# <ul>
# <li>Rowville</li>
# </ul>
# </li>
# Postcode found: 3178
# Suburbs found: 1
# Added: Rowville, 3178
#
# Processing item 162:
# <li><a href="https://postcodes-australia.com/postcodes/3179" title="Postcode 3179, Victoria">3179</a>
# <ul>
# <li>Scoresby</li>
# </ul>
# </li>
# Postcode found: 3179
# Suburbs found: 1
# Added: Scoresby, 3179
#
# Processing item 163:
# <li><a href="https://postcodes-australia.com/postcodes/3180" title="Postcode 3180, Victoria">3180</a>
# <ul>
# <li>Knoxfield</li>
# </ul>
# </li>
# Postcode found: 3180
# Suburbs found: 1
# Added: Knoxfield, 3180
#
# Processing item 164:
# <li><a href="https://postcodes-australia.com/postcodes/3181" title="Postcode 3181, Victoria">3181</a>
# <ul>
# <li>Prahran</li>
# <li>Windsor</li>
# </ul>
# </li>
# Postcode found: 3181
# Suburbs found: 2
# Added: Prahran, 3181
# Added: Windsor, 3181
#
# Processing item 165:
# <li><a href="https://postcodes-australia.com/postcodes/3182" title="Postcode 3182, Victoria">3182</a>
# <ul>
# <li>St Kilda</li>
# <li>St Kilda West</li>
# </ul>
# </li>
# Postcode found: 3182
# Suburbs found: 2
# Added: St Kilda, 3182
# Added: St Kilda West, 3182
#
# Processing item 166:
# <li><a href="https://postcodes-australia.com/postcodes/3183" title="Postcode 3183, Victoria">3183</a>
# <ul>
# <li>Balaclava</li>
# <li>St Kilda East</li>
# </ul>
# </li>
# Postcode found: 3183
# Suburbs found: 2
# Added: Balaclava, 3183
# Added: St Kilda East, 3183
#
# Processing item 167:
# <li><a href="https://postcodes-australia.com/postcodes/3184" title="Postcode 3184, Victoria">3184</a>
# <ul>
# <li>Elwood</li>
# </ul>
# </li>
# Postcode found: 3184
# Suburbs found: 1
# Added: Elwood, 3184
#
# Processing item 168:
# <li><a href="https://postcodes-australia.com/postcodes/3185" title="Postcode 3185, Victoria">3185</a>
# <ul>
# <li>Elsternwick</li>
# <li>Gardenvale</li>
# <li>Ripponlea</li>
# </ul>
# </li>
# Postcode found: 3185
# Suburbs found: 3
# Added: Elsternwick, 3185
# Added: Gardenvale, 3185
# Added: Ripponlea, 3185
#
# Processing item 169:
# <li><a href="https://postcodes-australia.com/postcodes/3186" title="Postcode 3186, Victoria">3186</a>
# <ul>
# <li>Brighton</li>
# <li>Brighton North</li>
# </ul>
# </li>
# Postcode found: 3186
# Suburbs found: 2
# Added: Brighton, 3186
# Added: Brighton North, 3186
#
# Processing item 170:
# <li><a href="https://postcodes-australia.com/postcodes/3187" title="Postcode 3187, Victoria">3187</a>
# <ul>
# <li>Brighton East</li>
# </ul>
# </li>
# Postcode found: 3187
# Suburbs found: 1
# Added: Brighton East, 3187
#
# Processing item 171:
# <li><a href="https://postcodes-australia.com/postcodes/3188" title="Postcode 3188, Victoria">3188</a>
# <ul>
# <li>Hampton</li>
# <li>Hampton East</li>
# </ul>
# </li>
# Postcode found: 3188
# Suburbs found: 2
# Added: Hampton, 3188
# Added: Hampton East, 3188
#
# Processing item 172:
# <li><a href="https://postcodes-australia.com/postcodes/3189" title="Postcode 3189, Victoria">3189</a>
# <ul>
# <li>Moorabbin</li>
# <li>Moorabbin East</li>
# </ul>
# </li>
# Postcode found: 3189
# Suburbs found: 2
# Added: Moorabbin, 3189
# Added: Moorabbin East, 3189
#
# Processing item 173:
# <li><a href="https://postcodes-australia.com/postcodes/3190" title="Postcode 3190, Victoria">3190</a>
# <ul>
# <li>Highett</li>
# </ul>
# </li>
# Postcode found: 3190
# Suburbs found: 1
# Added: Highett, 3190
#
# Processing item 174:
# <li><a href="https://postcodes-australia.com/postcodes/3191" title="Postcode 3191, Victoria">3191</a>
# <ul>
# <li>Sandringham</li>
# </ul>
# </li>
# Postcode found: 3191
# Suburbs found: 1
# Added: Sandringham, 3191
#
# Processing item 175:
# <li><a href="https://postcodes-australia.com/postcodes/3192" title="Postcode 3192, Victoria">3192</a>
# <ul>
# <li>Cheltenham</li>
# <li>Southland Centre</li>
# </ul>
# </li>
# Postcode found: 3192
# Suburbs found: 2
# Added: Cheltenham, 3192
# Added: Southland Centre, 3192
#
# Processing item 176:
# <li><a href="https://postcodes-australia.com/postcodes/3193" title="Postcode 3193, Victoria">3193</a>
# <ul>
# <li>Beaumaris</li>
# <li>Black Rock</li>
# </ul>
# </li>
# Postcode found: 3193
# Suburbs found: 2
# Added: Beaumaris, 3193
# Added: Black Rock, 3193
#
# Processing item 177:
# <li><a href="https://postcodes-australia.com/postcodes/3194" title="Postcode 3194, Victoria">3194</a>
# <ul>
# <li>Mentone</li>
# <li>Moorabbin Airport</li>
# </ul>
# </li>
# Postcode found: 3194
# Suburbs found: 2
# Added: Mentone, 3194
# Added: Moorabbin Airport, 3194
#
# Processing item 178:
# <li><a href="https://postcodes-australia.com/postcodes/3195" title="Postcode 3195, Victoria">3195</a>
# <ul>
# <li>Aspendale</li>
# <li>Aspendale Gardens</li>
# <li>Braeside</li>
# <li>Mordialloc</li>
# <li>Parkdale</li>
# <li>Waterways</li>
# </ul>
# </li>
# Postcode found: 3195
# Suburbs found: 6
# Added: Aspendale, 3195
# Added: Aspendale Gardens, 3195
# Added: Braeside, 3195
# Added: Mordialloc, 3195
# Added: Parkdale, 3195
# Added: Waterways, 3195
#
# Processing item 179:
# <li><a href="https://postcodes-australia.com/postcodes/3196" title="Postcode 3196, Victoria">3196</a>
# <ul>
# <li>Bonbeach</li>
# <li>Chelsea</li>
# <li>Chelsea Heights</li>
# <li>Edithvale</li>
# </ul>
# </li>
# Postcode found: 3196
# Suburbs found: 4
# Added: Bonbeach, 3196
# Added: Chelsea, 3196
# Added: Chelsea Heights, 3196
# Added: Edithvale, 3196
#
# Processing item 180:
# ...
#
# Processing item 704:
# <li><a href="https://postcodes-australia.com/postcodes/3981" title="Postcode 3981, Victoria">3981</a>
# <ul>
# <li>Bayles</li>
# <li>Catani</li>
# <li>Dalmore</li>
# <li>Heath Hill</li>
# <li>Koo Wee Rup</li>
# <li>Koo Wee Rup North</li>
# <li>Yannathan</li>
# </ul>
# </li>
# Postcode found: 3981
# Suburbs found: 7
# Added: Bayles, 3981
# Added: Catani, 3981
# Added: Dalmore, 3981
# Added: Heath Hill, 3981
# Added: Koo Wee Rup, 3981
# Added: Koo Wee Rup North, 3981
# Added: Yannathan, 3981
#
# Processing item 705:
# <li><a href="https://postcodes-australia.com/postcodes/3984" title="Postcode 3984, Victoria">3984</a>
# <ul>
# <li>Adams Estate</li>
# <li>Caldermeade</li>
# <li>Corinella</li>
# <li>Coronet Bay</li>
# <li>Grantville</li>
# <li>Jam Jerrup</li>
# <li>Lang Lang</li>
# <li>Lang Lang East</li>
# <li>Monomeith</li>
# <li>Pioneer Bay</li>
# <li>Queensferry</li>
# <li>Tenby Point</li>
# <li>The Gurdies</li>
# </ul>
# </li>
# Postcode found: 3984
# Suburbs found: 13
# Added: Adams Estate, 3984
# Added: Caldermeade, 3984
# Added: Corinella, 3984
# Added: Coronet Bay, 3984
# Added: Grantville, 3984
# Added: Jam Jerrup, 3984
# Added: Lang Lang, 3984
# Added: Lang Lang East, 3984
# Added: Monomeith, 3984
# Added: Pioneer Bay, 3984
# Added: Queensferry, 3984
# Added: Tenby Point, 3984
# Added: The Gurdies, 3984
#
# Processing item 706:
# <li><a href="https://postcodes-australia.com/postcodes/3987" title="Postcode 3987, Victoria">3987</a>
# <ul>
# <li>Nyora</li>
# </ul>
# </li>
# Postcode found: 3987
# Suburbs found: 1
# Added: Nyora, 3987
#
# Processing item 707:
# <li><a href="https://postcodes-australia.com/postcodes/3988" title="Postcode 3988, Victoria">3988</a>
# <ul>
# <li>Mountain View</li>
# <li>Poowong</li>
# <li>Poowong East</li>
# <li>Poowong North</li>
# </ul>
# </li>
# Postcode found: 3988
# Suburbs found: 4
# Added: Mountain View, 3988
# Added: Poowong, 3988
# Added: Poowong East, 3988
# Added: Poowong North, 3988
#
# Processing item 708:
# <li><a href="https://postcodes-australia.com/postcodes/3989" title="Postcode 3989, Victoria">3989</a>
# <ul>
# <li>St Helier</li>
# </ul>
# </li>
# Postcode found: 3989
# Suburbs found: 1
# Added: St Helier, 3989
#
# Processing item 709:
# <li><a href="https://postcodes-australia.com/postcodes/3990" title="Postcode 3990, Victoria">3990</a>
# <ul>
# <li>Glen Forbes</li>
# </ul>
# </li>
# Postcode found: 3990
# Suburbs found: 1
# Added: Glen Forbes, 3990
#
# Processing item 710:
# <li><a href="https://postcodes-australia.com/postcodes/3991" title="Postcode 3991, Victoria">3991</a>
# <ul>
# <li>Bass</li>
# </ul>
# </li>
# Postcode found: 3991
# Suburbs found: 1
# Added: Bass, 3991
#
# Processing item 711:
# <li><a href="https://postcodes-australia.com/postcodes/3992" title="Postcode 3992, Victoria">3992</a>
# <ul>
# <li>Blackwood Forest</li>
# <li>Dalyston</li>
# <li>Ryanston</li>
# <li>West Creek</li>
# </ul>
# </li>
# Postcode found: 3992
# Suburbs found: 4
# Added: Blackwood Forest, 3992
# Added: Dalyston, 3992
# Added: Ryanston, 3992
# Added: West Creek, 3992
#
# Processing item 712:
# <li><a href="https://postcodes-australia.com/postcodes/3995" title="Postcode 3995, Victoria">3995</a>
# <ul>
# <li>Anderson</li>
# <li>Archies Creek</li>
# <li>Cape Paterson</li>
# <li>Harmers Haven</li>
# <li>Hicksborough</li>
# <li>Kilcunda</li>
# <li>Lance Creek</li>
# <li>North Wonthaggi</li>
# <li>Powlett River</li>
# <li>South Dudley</li>
# <li>St Clair</li>
# <li>Wattle Bank</li>
# <li>Wonthaggi</li>
# <li>Woolamai</li>
# </ul>
# </li>
# Postcode found: 3995
# Suburbs found: 14
# Added: Anderson, 3995
# Added: Archies Creek, 3995
# Added: Cape Paterson, 3995
# Added: Harmers Haven, 3995
# Added: Hicksborough, 3995
# Added: Kilcunda, 3995
# Added: Lance Creek, 3995
# Added: North Wonthaggi, 3995
# Added: Powlett River, 3995
# Added: South Dudley, 3995
# Added: St Clair, 3995
# Added: Wattle Bank, 3995
# Added: Wonthaggi, 3995
# Added: Woolamai, 3995
#
# Processing item 713:
# <li><a href="https://postcodes-australia.com/postcodes/3996" title="Postcode 3996, Victoria">3996</a>
# <ul>
# <li>Inverloch</li>
# <li>Pound Creek</li>
# </ul>
# </li>
# Postcode found: 3996
# Suburbs found: 2
# Added: Inverloch, 3996
# Added: Pound Creek, 3996
#
# Processing item 714:
# <li><a href="https://postcodes-australia.com/postcodes/8001" title="Postcode 8001, Victoria">8001</a>
# <ul>
# <li>Melbourne</li>
# </ul>
# </li>
# Postcode found: 8001
# Suburbs found: 1
# Added: Melbourne, 8001
#
# Processing item 715:
# <li><a href="https://postcodes-australia.com/postcodes/8002" title="Postcode 8002, Victoria">8002</a>
# <ul>
# <li>East Melbourne</li>
# </ul>
# </li>
# Postcode found: 8002
# Suburbs found: 1
# Added: East Melbourne, 8002
#
# Processing item 716:
# <li><a href="https://postcodes-australia.com/postcodes/8003" title="Postcode 8003, Victoria">8003</a>
# <ul>
# <li>Administrative Postcode Only</li>
# </ul>
# </li>
# Postcode found: 8003
# Suburbs found: 1
# Added: Administrative Postcode Only, 8003
#
# Processing item 717:
# <li><a href="https://postcodes-australia.com/postcodes/8004" title="Postcode 8004, Victoria">8004</a>
# <ul>
# <li>Administrative Postcode Only</li>
# </ul>
# </li>
# Postcode found: 8004
# Suburbs found: 1
# Added: Administrative Postcode Only, 8004
#
# Processing item 718:
# <li><a href="https://postcodes-australia.com/postcodes/8005" title="Postcode 8005, Victoria">8005</a>
# <ul>
# <li>World Trade Centre</li>
# </ul>
# </li>
# Postcode found: 8005
# Suburbs found: 1
# Added: World Trade Centre, 8005
#
# Processing item 719:
# <li><a href="https://postcodes-australia.com/postcodes/8006" title="Postcode 8006, Victoria">8006</a>
# <ul>
# <li>Administrative Postcode Only</li>
# </ul>
# </li>
# Postcode found: 8006
# Suburbs found: 1
# Added: Administrative Postcode Only, 8006
#
# Processing item 720:
# <li><a href="https://postcodes-australia.com/postcodes/8007" title="Postcode 8007, Victoria">8007</a>
# <ul>
# <li>Administrative Postcode Only</li>
# </ul>
# </li>
# Postcode found: 8007
# Suburbs found: 1
# Added: Administrative Postcode Only, 8007
#
# Processing item 721:
# <li><a href="https://postcodes-australia.com/postcodes/8008" title="Postcode 8008, Victoria">8008</a>
# <ul>
# <li>Administrative Postcode Only</li>
# </ul>
# </li>
# Postcode found: 8008
# Suburbs found: 1
# Added: Administrative Postcode Only, 8008
#
# Processing item 722:
# <li><a href="https://postcodes-australia.com/postcodes/8009" title="Postcode 8009, Victoria">8009</a>
# <ul>
# <li>Administrative Postcode Only</li>
# </ul>
# </li>
# Postcode found: 8009
# Suburbs found: 1
# Added: Administrative Postcode Only, 8009
#
# Processing item 723:
# <li><a href="https://postcodes-australia.com/postcodes/8010" title="Postcode 8010, Victoria">8010</a>
# <ul>
# <li>Administrative Postcode Only</li>
# </ul>
# </li>
# Postcode found: 8010
# Suburbs found: 1
# Added: Administrative Postcode Only, 8010
#
# Processing item 724:
# <li><a href="https://postcodes-australia.com/postcodes/8045" title="Postcode 8045, Victoria">8045</a>
# <ul>
# <li>Melbourne</li>
# </ul>
# </li>
# Postcode found: 8045
# Suburbs found: 1
# Added: Melbourne, 8045
#
# Processing item 725:
# <li><a href="https://postcodes-australia.com/postcodes/8051" title="Postcode 8051, Victoria">8051</a>
# <ul>
# <li>Melbourne</li>
# </ul>
# </li>
# Postcode found: 8051
# Suburbs found: 1
# Added: Melbourne, 8051
#
# Processing item 726:
# <li><a href="https://postcodes-australia.com/postcodes/8060" title="Postcode 8060, Victoria">8060</a>
# <ul>
# <li>Melbourne</li>
# </ul>
# </li>
# Postcode found: 8060
# Suburbs found: 1
# Added: Melbourne, 8060
#
# Processing item 727:
# <li><a href="https://postcodes-australia.com/postcodes/8061" title="Postcode 8061, Victoria">8061</a>
# <ul>
# <li>Melbourne</li>
# </ul>
# </li>
# Postcode found: 8061
# Suburbs found: 1
# Added: Melbourne, 8061
#
# Processing item 728:
# <li><a href="https://postcodes-australia.com/postcodes/8066" title="Postcode 8066, Victoria">8066</a>
# <ul>
# <li>Melbourne</li>
# </ul>
# </li>
# Postcode found: 8066
# Suburbs found: 1
# Added: Melbourne, 8066
#
# Processing item 729:
# <li><a href="https://postcodes-australia.com/postcodes/8069" title="Postcode 8069, Victoria">8069</a>
# <ul>
# <li>Melbourne</li>
# </ul>
# </li>
# Postcode found: 8069
# Suburbs found: 1
# Added: Melbourne, 8069
#
# Processing item 730:
# <li><a href="https://postcodes-australia.com/postcodes/8070" title="Postcode 8070, Victoria">8070</a>
# <ul>
# <li>Melbourne</li>
# </ul>
# </li>
# Postcode found: 8070
# Suburbs found: 1
# Added: Melbourne, 8070
#
# Processing item 731:
# <li><a href="https://postcodes-australia.com/postcodes/8071" title="Postcode 8071, Victoria">8071</a>
# <ul>
# <li>Melbourne</li>
# </ul>
# </li>
# Postcode found: 8071
# Suburbs found: 1
# Added: Melbourne, 8071
#
# Processing item 732:
# <li><a href="https://postcodes-australia.com/postcodes/8100" title="Postcode 8100, Victoria">8100</a>
# <ul>
# <li>Melbourne</li>
# </ul>
# </li>
# Postcode found: 8100
# Suburbs found: 1
# Added: Melbourne, 8100
#
# Processing item 733:
# <li><a href="https://postcodes-australia.com/postcodes/8101" title="Postcode 8101, Victoria">8101</a>
# <ul>
# <li>Melbourne</li>
# </ul>
# </li>
# Postcode found: 8101
# Suburbs found: 1
# Added: Melbourne, 8101
#
# Processing item 734:
# <li><a href="https://postcodes-australia.com/postcodes/8102" title="Postcode 8102, Victoria">8102</a>
# <ul>
# <li>Melbourne</li>
# </ul>
# </li>
# Postcode found: 8102
# Suburbs found: 1
# Added: Melbourne, 8102
#
# Processing item 735:
# <li><a href="https://postcodes-australia.com/postcodes/8103" title="Postcode 8103, Victoria">8103</a>
# <ul>
# <li>Melbourne</li>
# </ul>
# </li>
# Postcode found: 8103
# Suburbs found: 1
# Added: Melbourne, 8103
#
# Processing item 736:
# <li><a href="https://postcodes-australia.com/postcodes/8107" title="Postcode 8107, Victoria">8107</a>
# <ul>
# <li>Melbourne</li>
# </ul>
# </li>
# Postcode found: 8107
# Suburbs found: 1
# Added: Melbourne, 8107
#
# Processing item 737:
# <li><a href="https://postcodes-australia.com/postcodes/8108" title="Postcode 8108, Victoria">8108</a>
# <ul>
# <li>Melbourne</li>
# </ul>
# </li>
# Postcode found: 8108
# Suburbs found: 1
# Added: Melbourne, 8108
#
# Processing item 738:
# <li><a href="https://postcodes-australia.com/postcodes/8111" title="Postcode 8111, Victoria">8111</a>
# <ul>
# <li>Melbourne</li>
# </ul>
# </li>
# Postcode found: 8111
# Suburbs found: 1
# Added: Melbourne, 8111
#
# Processing item 739:
# <li><a href="https://postcodes-australia.com/postcodes/8120" title="Postcode 8120, Victoria">8120</a>
# <ul>
# <li>Melbourne</li>
# </ul>
# </li>
# Postcode found: 8120
# Suburbs found: 1
# Added: Melbourne, 8120
#
# Processing item 740:
# <li><a href="https://postcodes-australia.com/postcodes/8205" title="Postcode 8205, Victoria">8205</a>
# <ul>
# <li>Melbourne</li>
# </ul>
# </li>
# Postcode found: 8205
# Suburbs found: 1
# Added: Melbourne, 8205
#
# Processing item 741:
# <li><a href="https://postcodes-australia.com/postcodes/8383" title="Postcode 8383, Victoria">8383</a>
# <ul>
# <li>Melbourne</li>
# </ul>
# </li>
# Postcode found: 8383
# Suburbs found: 1
# Added: Melbourne, 8383
#
# Processing item 742:
# <li><a href="https://postcodes-australia.com/postcodes/8386" title="Postcode 8386, Victoria">8386</a>
# <ul>
# <li>Melbourne</li>
# </ul>
# </li>
# Postcode found: 8386
# Suburbs found: 1
# Added: Melbourne, 8386
#
# Processing item 743:
# <li><a href="https://postcodes-australia.com/postcodes/8388" title="Postcode 8388, Victoria">8388</a>
# <ul>
# <li>Melbourne</li>
# </ul>
# </li>
# Postcode found: 8388
# Suburbs found: 1
# Added: Melbourne, 8388
#
# Processing item 744:
# <li><a href="https://postcodes-australia.com/postcodes/8390" title="Postcode 8390, Victoria">8390</a>
# <ul>
# <li>Melbourne</li>
# </ul>
# </li>
# Postcode found: 8390
# Suburbs found: 1
# Added: Melbourne, 8390
#
# Processing item 745:
# <li><a href="https://postcodes-australia.com/postcodes/8393" title="Postcode 8393, Victoria">8393</a>
# <ul>
# <li>Melbourne</li>
# </ul>
# </li>
# Postcode found: 8393
# Suburbs found: 1
# Added: Melbourne, 8393
#
# Processing item 746:
# <li><a href="https://postcodes-australia.com/postcodes/8394" title="Postcode 8394, Victoria">8394</a>
# <ul>
# <li>Melbourne</li>
# </ul>
# </li>
# Postcode found: 8394
# Suburbs found: 1
# Added: Melbourne, 8394
#
# Processing item 747:
# <li><a href="https://postcodes-australia.com/postcodes/8396" title="Postcode 8396, Victoria">8396</a>
# <ul>
# <li>Melbourne</li>
# </ul>
# </li>
# Postcode found: 8396
# Suburbs found: 1
# Added: Melbourne, 8396
#
# Processing item 748:
# <li><a href="https://postcodes-australia.com/postcodes/8399" title="Postcode 8399, Victoria">8399</a>
# <ul>
# <li>Melbourne</li>
# </ul>
# </li>
# Postcode found: 8399
# Suburbs found: 1
# Added: Melbourne, 8399
#
# Processing item 749:
# <li><a href="https://postcodes-australia.com/postcodes/8500" title="Postcode 8500, Victoria">8500</a>
# <ul>
# <li>North Melbourne</li>
# </ul>
# </li>
# Postcode found: 8500
# Suburbs found: 1
# Added: North Melbourne, 8500
#
# Processing item 750:
# <li><a href="https://postcodes-australia.com/postcodes/8507" title="Postcode 8507, Victoria">8507</a>
# <ul>
# <li>Carlton</li>
# </ul>
# </li>
# Postcode found: 8507
# Suburbs found: 1
# Added: Carlton, 8507
#
# Processing item 751:
# <li><a href="https://postcodes-australia.com/postcodes/8538" title="Postcode 8538, Victoria">8538</a>
# <ul>
# <li>Brunswick</li>
# </ul>
# </li>
# Postcode found: 8538
# Suburbs found: 1
# Added: Brunswick, 8538
#
# Processing item 752:
# <li><a href="https://postcodes-australia.com/postcodes/8557" title="Postcode 8557, Victoria">8557</a>
# <ul>
# <li>Fitzroy</li>
# </ul>
# </li>
# Postcode found: 8557
# Suburbs found: 1
# Added: Fitzroy, 8557
#
# Processing item 753:
# <li><a href="https://postcodes-australia.com/postcodes/8576" title="Postcode 8576, Victoria">8576</a>
# <ul>
# <li>Ivanhoe</li>
# </ul>
# </li>
# Postcode found: 8576
# Suburbs found: 1
# Added: Ivanhoe, 8576
#
# Processing item 754:
# <li><a href="https://postcodes-australia.com/postcodes/8622" title="Postcode 8622, Victoria">8622</a>
# <ul>
# <li>Hawthorn</li>
# </ul>
# </li>
# Postcode found: 8622
# Suburbs found: 1
# Added: Hawthorn, 8622
#
# Processing item 755:
# <li><a href="https://postcodes-australia.com/postcodes/8626" title="Postcode 8626, Victoria">8626</a>
# <ul>
# <li>Camberwell</li>
# </ul>
# </li>
# Postcode found: 8626
# Suburbs found: 1
# Added: Camberwell, 8626
#
# Processing item 756:
# <li><a href="https://postcodes-australia.com/postcodes/8627" title="Postcode 8627, Victoria">8627</a>
# <ul>
# <li>Camberwell</li>
# </ul>
# </li>
# Postcode found: 8627
# Suburbs found: 1
# Added: Camberwell, 8627
#
# Processing item 757:
# <li><a href="https://postcodes-australia.com/postcodes/8659" title="Postcode 8659, Victoria">8659</a>
# <ul>
# <li>Administrative Postcode Only</li>
# </ul>
# </li>
# Postcode found: 8659
# Suburbs found: 1
# Added: Administrative Postcode Only, 8659
#
# Processing item 758:
# <li><a href="https://postcodes-australia.com/postcodes/8785" title="Postcode 8785, Victoria">8785</a>
# <ul>
# <li>Dandenong</li>
# </ul>
# </li>
# Postcode found: 8785
# Suburbs found: 1
# Added: Dandenong, 8785
#
# Processing item 759:
# <li><a href="https://postcodes-australia.com/postcodes/8865" title="Postcode 8865, Victoria">8865</a>
# <ul>
# <li>South Melbourne</li>
# </ul>
# </li>
# Postcode found: 8865
# Suburbs found: 1
# Added: South Melbourne, 8865
#
# Processing item 760:
# <li><a href="https://postcodes-australia.com/postcodes/8873" title="Postcode 8873, Victoria">8873</a>
# <ul>
# <li>Port Melbourne</li>
# </ul>
# <br/><br/>
# <p>• <a href="#" title="Top of page">Back to top of page</a></p>
# <p>• <a href="https://postcodes-australia.com/" title="Home Page">Return to home page</a></p>
# <br/>
# </li>
# Postcode found: 8873
# Suburbs found: 1
# Added: Port Melbourne, 8873
#
# Total entries extracted: 3080
#
# Filtered DataFrame shape: (239, 2)
# Filtered CSV file written successfully
#
# First 5 entries of the filtered data:
#            Suburb  Postcode
# 0       Melbourne      3000
# 1       Melbourne      3001
# 2  East Melbourne      3002
# 3  West Melbourne      3003
# 4       Melbourne      3004
# /var/folders/nm/khyl2f0x48l1b8wtrp1l9gjw0000gn/T/ipykernel_550/3043711028.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Postcode'] = filtered_df['Postcode'].astype(int)
#               Suburb  Postcode
# 0          Melbourne      3000
# 1          Melbourne      3001
# 2     East Melbourne      3002
# 3     West Melbourne      3003
# 4          Melbourne      3004
# ...              ...       ...
# 2841      Mornington      3931
# 2845         Dromana      3936
# 2860         Portsea      3944
# 2964    Hampton Park      3976
# 2966      Cranbourne      3977
#
# [201 rows x 2 columns]

# %%
url = 'https://www.domain.com.au/508-408-lonsdale-street-melbourne-vic-3000-17166328'

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'}
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-build-git-hash="4135e2bc2e79557ea1debc6c6a2b2e220ba80dae" data-build-id="master-6261" data-build-time="Wed Aug 28 2024 14:18:38 GMT+1000 (Australian Eastern Standard Time)" data-version="9.126.0" lang="en-AU">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    508/408 Lonsdale Street, Melbourne VIC 3000 - Apartment For Rent | Domain
#   </title>
#   <meta content="View this 1 bathroom rental apartment at 508/408 Lonsdale Street, Melbourne VIC 3000. Available from Friday, 10 February 2023. Contact agent for price." name="description"/>
#   <meta content="508/408 Lonsdale Street, Melbourne VIC 3000 - Apartment For Rent | Domain" property="og:title"/>
#   <meta content="View this 1 bathroom rental apartment at 508/408 Lonsdale Street, Melbourne VIC 3000. Available from Friday, 10 February 2023. Contact agent for price." property="og:description"/>
#   <meta content="product" property="og:type"/>
#   <meta content="Domain" property="og:site_name"/>
#   <meta content="https://www.domain.com.au/508-408-lonsdale-street-melbourne-vic-3000-17166328" property="og:url"/>
#   <meta content="https://bucket-api.domain.com.au/v1/bucket/image/17166328_1_1_240818_111609-w2000-h1334" property="og:image"/>
#   <meta content="505328276158724" property="fb:app_id"/>
#   <meta content="domain.com.au://propertyDetails/17166328" property="al:ios:url"/>
#   <meta content="319908646" property="al:ios:app_store_id"/>
#   <meta content="Domain Real Estate and Property" property="al:ios:app_name"/>
#   <meta content="domain://listing/17166328" property="al:android:url"/>
#   <meta content="com.fairfax.domain" property="al:android:package"/>
#   <meta content="Domain" property="al:android:app_name"/>
#   <meta content="gallery" name="twitter:card"/>
#   <meta content="@Domaincomau" name="twitter:site"/>
#   <meta content="508/408 Lonsdale Street, Melbourne VIC 3000 - Apartment For Rent | Domain" name="twitter:title"/>
#   <meta content="View this 1 bathroom rental apartment at 508/408 Lonsdale Street, Melbourne VIC 3000. Available from Friday, 10 February 2023. Contact agent for price." name="twitter:description"/>
#   <meta content="https://bucket-api.domain.com.au/v1/bucket/image/17166328_1_1_240818_111609-w2000-h1334" name="twitter:image0"/>
#   <meta content="https://bucket-api.domain.com.au/v1/bucket/image/17166328_2_1_240818_111609-w2000-h1333" name="twitter:image1"/>
#   <meta content="https://bucket-api.domain.com.au/v1/bucket/image/17166328_3_1_240818_111609-w2000-h1333" name="twitter:image2"/>
#   <meta content="https://bucket-api.domain.com.au/v1/bucket/image/17166328_4_1_240818_111609-w2000-h1333" name="twitter:image3"/>
#   <link href="android-app://com.fairfax.domain/https/www.domain.com.au/508-408-lonsdale-street-melbourne-vic-3000-17166328" rel="alternate"/>
#   <link href="ios-app://319908646/domain.com.au/domainapp" rel="alternate"/>
#   <meta content="elitePp" name="product-type"/>
#   <script>
#    var digitalData = {"page":{"pageInfo":{"agencyId":33232,"author":33232,"bookingSystem":"Inspect Real Estate","effectiveDate":"2024-08-19T09:16:09.123","isEmbeddedApp":false,"issueDate":"2024-08-19T09:16:09.120","pageId":17166328,"pageName":"property details - rent - 17166328 - 508/408 lonsdale street melbourne vic 3000","property":{"rentalMethod":"rent","address":"508/408 Lonsdale Street, Melbourne VIC 3000","adtype":"elitePp","agency":"Belle Property South Melbourne","agencyId":33232,"agentNames":"Cooper Cavallo","bathrooms":1,"bedrooms":0,"daysListed":15,"dateListed":"2024-08-19T09:16:10.000","inspectionsCount":0,"hasPhoto":true,"hasFloorplan":false,"hasDisplayPrice":true,"hasDescription":true,"descriptionHasEmail":false,"descriptionHasPhone":false,"hasSOI":false,"rentalSystem":"2Apply","virtualTour":false,"floorPlansCount":0,"images":["https://bucket-api.domain.com.au/v1/bucket/image/17166328_1_1_240818_111609-w2000-h1334","https://bucket-api.domain.com.au/v1/bucket/image/17166328_2_1_240818_111609-w2000-h1333","https://bucket-api.domain.com.au/v1/bucket/image/17166328_3_1_240818_111609-w2000-h1333","https://bucket-api.domain.com.au/v1/bucket/image/17166328_4_1_240818_111609-w2000-h1333","https://bucket-api.domain.com.au/v1/bucket/image/17166328_5_1_240818_111609-w2000-h1333"],"onlineAuctionAvailable":"None","parking":0,"photoCount":5,"postcode":"3000","price":"$360 per week","primaryPropertyType":"Apartment","propertyFeatures":"Built-In Wardrobes","structuredFeatures":[{"name":"Built in wardrobes","category":"Indoor","source":"advertiser"}],"propertyId":"SZ-0489-XR","secondaryPropertyType":"Apartment / Unit / Flat","state":"VIC","suburb":"Melbourne","videoCount":0,"x-message":"domain-propertyinfo"},"nbnDetails":"FTTB","suburbId":25807,"source":"Unknown","brand":"domain","generator":"DO","sysEnv":"responsive"},"category":{"primaryCategory":"Rent","subCategory1":"Property Details","pageType":"Listing"},"optimize":{"shortlistExperimentFlag":true}},"titan":{"adZone":"rent/details","contentWidth":"","adKeyValues":{"cat":"rent","cat1":"details","ctype":"listing","e":"www.domain.com.au","locstate":"vic","locarea":["melbourne_city_council_greater_area"],"locsuburb":["melbourne"],"locpostcode":["3000"],"pageId":17166328,"pageName":"property details - rent - 17166328 - 508/408 lonsdale street melbourne vic 3000","address":"508/408 Lonsdale Street, Melbourne VIC 3000","usertype":"rent","medianPrice":"0K","proptypes":["apartment_unit_flat"],"bedrooms":0},"adSite":"DOMAIN.COM.AU","adSlots":[]},"titanFromGraph":{"adSite":"DOMAIN.COM.AU","adSlots":[],"adZone":"rent/details","contentWidth":"","adKeyValues":{"cat":"rent","cat1":"details","ctype":"listing","e":"www.domain.com.au","locstate":"vic","locarea":["melbourne_city_council_greater_area"],"locsuburb":["melbourne"],"locpostcode":["3000"],"pageId":17166328,"pageName":"property details - rent - 17166328 - 508/408 lonsdale street melbourne vic 3000","address":"508/408 Lonsdale Street, Melbourne VIC 3000","usertype":"rent","medianPrice":"0K","proptypes":["apartment_unit_flat"]}},"adLoader":"prebid","pageFromGraph":{"pageInfo":{"brand":"domain","generator":"DO","sysEnv":"responsive","isEmbeddedApp":false,"agencyId":33232,"author":33232,"bookingSystem":"IRE","effectiveDate":"2024-08-19T09:16:09.123","issueDate":"2024-08-19T09:16:09.120","pageId":17166328,"pageName":"property details - rent - 17166328 - 508/408 lonsdale street melbourne vic 3000","property":{"rentalMethod":"rent","address":"508/408 Lonsdale Street, Melbourne VIC 3000","adtype":"elitePp","agency":"Belle Property South Melbourne","agencyId":33232,"agentNames":"Cooper Cavallo","bathrooms":1,"daysListed":15,"dateListed":"2024-08-19T09:16:10.000","inspectionsCount":0,"hasPhoto":true,"hasFloorplan":false,"hasDisplayPrice":true,"hasDescription":true,"descriptionHasEmail":false,"descriptionHasPhone":false,"hasSOI":false,"rentalSystem":"IRE","virtualTour":false,"floorPlansCount":0,"images":["https://bucket-api.domain.com.au/v1/buc ...
#               var dataLayer = [digitalData];
#   </script>
#   <link href="https://www.domain.com.au/508-408-lonsdale-street-melbourne-vic-3000-17166328" rel="canonical"/>
#   <link as="image" href="https://rimh2.domainstatic.com.au/b0WG4q6lNgRMFWIt_QGjwadF1Yk=/fit-in/600x800/filters:format(jpeg):quality(80):no_upscale()/17166328_1_1_240818_111609-w2000-h1334" media="(max-width: 623px)" rel="preload"/>
#   <link as="image" href="https://rimh2.domainstatic.com.au/RI_sGYtcAGPqqCQwPcFqsGKAPV8=/fit-in/1020x1020/filters:format(jpeg):quality(80):no_upscale()/17166328_1_1_240818_111609-w2000-h1334" media="(min-width: 624px) and (max-width: 1020px)" rel="preload"/>
#   <link as="image" href="https://rimh2.domainstatic.com.au/-N8fzliABmhVoAVYGErqWTT7Gi8=/fit-in/1920x1080/filters:format(jpeg):quality(80):no_upscale()/17166328_1_1_240818_111609-w2000-h1334" media="(min-width: 1021px)" rel="preload"/>
#   <script>
#    !function(a,b,c,d,e,f,g,h){a.RaygunObject=e,a[e]=a[e]||function(){
#       (a[e].o=a[e].o||[]).push(arguments)},f=b.createElement(c),g=b.getElementsByTagName(c)[0],
#       f.async=1,f.src=d,g.parentNode.insertBefore(f,g),h=a.onerror,a.onerror=function(b,c,d,f,g){
#       h&&h(b,c,d,f,g),g||(g=new Error(b)),a[e].q=a[e].q||[],a[e].q.push({
#       e:g})}}(window,document,"script","//cdn.raygun.io/raygun4js/raygun.min.js","rg4js");
#
#       rg4js('apiKey', 'Jc2EG8UJC5PYaGq58+JtVA==');
#       rg4js('enableCrashReporting', true);
#       rg4js('options', {
#         ignore3rdPartyErrors: true,
#         excludedHostnames: ['www.googletagmanager.com']
#       });
#       rg4js('withTags', ["isListingDetails","isResidentialListingDetails"])
#       rg4js('setVersion', '9.126.0');
#   </script>
#   <script async="" src="https://prod.adspsp.com/adb.4226848.min.js" type="text/javascript">
#   </script>
#   <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js" type="text/javascript">
#   </script>
#   <script async="" nonce="eABCkO3S3fUXHZr8q92MvA" src="https://fundingchoicesmessages.google.com/i/pub-2707137452631707?ers=1">
#   </script>
#   <script>
#    (function() {function signalGooglefcPresent() {if (!window.frames['googlefcPresent']) {if (document.body) {const iframe = document.createElement('iframe'); iframe.style = 'width: 0; height: 0; border: none; z-index: -1000; left: -1000px; top: -1000px;'; iframe.style.display = 'none'; iframe.name = 'googlefcPresent'; document.body.appendChild(iframe);} else {setTimeout(signalGooglefcPresent, 0);}}}signalGooglefcPresent();})();
#   </script>
#   <script type="application/ld+json">
#    [{"@context":"http://schema.org","@type":"Organization","name":"Domain","url":"https://www.domain.com.au","sameAs":["https://www.facebook.com/domain.com.au","https://twitter.com/domaincomau","https://plus.google.com/+domaincomau","https://www.linkedin.com/company/domain-com-au"]},{"@context":"http://schema.org","@type":"Residence","address":{"@type":"PostalAddress","streetAddress":"508/408 Lonsdale Street","addressLocality":"Melbourne","addressRegion":"VIC","postalCode":"3000"}},{"@context":"http://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"@id":"https://www.domain.com.au/rent/","name":"Rent"}},{"@type":"ListItem","position":2,"item":{"@id":"https://www.domain.com.au/rent/vic/","name":"VIC"}},{"@type":"ListItem","position":3,"item":{"@id":"https://www.domain.com.au/rent/melbourne-vic-3000/","name":"Melbourne"}},{"@type":"ListItem","position":4,"item":{"@id":"https://www.domain.com.au/rent/melbourne-vic-3000/apartment-unit-flat/","name":"Apartments"}},{"@type":"ListItem","position":5,"item":{"@id":"https://www.domain.com.au/rent/melbourne-vic-3000/apartment-unit-flat/0-bedroom/","name":"0-Bedroom"}},{"@type":"ListItem","position":6,"item":{"@id":"https://www.domain.com.au/508-408-lonsdale-street-melbourne-vic-3000-17166328","name":"508/408 Lonsdale Street, Melbourne VIC 3000"}}]},{"@context":"https://schema.org","@type":"FAQPage","mainEntity":[{"@type":"Question","name":"What is the weekly rent for 508/408 Lonsdale Street, Melbourne?","acceptedAnswer":{"@type":"Answer","text":"The weekly rent for 508/408 Lonsdale Street, Melbourne is $360 per week."}},{"@type":"Question","name":"When is 508/408 Lonsdale Street, Melbourne available to rent?","acceptedAnswer":{"@type":"Answer","text":"508/408 Lonsdale Street, Melbourne is available to rent now."}},{"@type":"Question","name":"How much is the rental bond for 508/408 Lonsdale Street, Melbourne?","acceptedAnswer":{"@type":"Answer","text":"The bond for 508/408 Lonsdale Street, Melbourne is $1564."}},{"@type":"Question","name":"What are the key property features of 508/408 Lonsdale Street, Melbourne?","acceptedAnswer":{"@type":"Answer","text":"Explore all key property features for 508/408 Lonsdale Street, Melbourne. <a href=\"#property-features\">Click here to find out more.</a>"}},{"@type":"Question","name":"What is the size of the property at 508/408 Lonsdale Street, Melbourne?","acceptedAnswer":{"@type":"Answer","text":"The property size for 508/408 Lonsdale Street, Melbourne has not been disclosed. To find detailed information on property size, <a href=\"#enquiry-form\">contact the agent.</a>"}},{"@type":"Question","name":"How many car spaces does 508/408 Lonsdale Street, Melbourne have?","acceptedAnswer":{"@type":"Answer","text":"There were no car spaces found on the listing for 508/408 Lonsdale Street, Melbourne."}}]}]
#   </script>
#   <script>
#    // load Branch
#             (function(b,r,a,n,c,h,_,s,d,k){if(!b[n]||!b[n]._q){for(;s<_.length;)c(h,_[s++]);d=r.createElement(a);d.async=1;d.src="https://cdn.branch.io/branch-latest.min.js";k=r.getElementsByTagName(a)[0];k.parentNode.insertBefore(d,k);b[n]=h}})(window,document,"script","branch",function(b,r){b[r]=function(){b._q.push([r,arguments])}},{_q:[],_v:1},"addListener applyCode autoAppIndex banner closeBanner closeJourney creditHistory credits data deepview deepviewCta first getCode init link logout redeem referrals removeListener sendSMS setBranchViewData setIdentity track validateCode trackCommerceEvent logEvent disableTracking".split(" "), 0);
#             // init Branch
#             branch.init('key_live_beUO960ie7SgOCONK8dfVgboqqe0mcGG');
#   </script>
#   <meta content="38" name="next-head-count"/>
#   <link href="//ads.rubiconproject.com" rel="dns-prefetch"/>
#   <link href="//fastlane.rubiconproject.com" rel="dns-prefetch"/>
#   <link href="https://s.domainstatic.com.au/design-tokens/3.39.0/css/domain-2022.css" rel="stylesheet"/>
#   <meta charset="utf-8"/>
#   <meta content="en-au" http-equiv="content-language"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <link href="//s.domainstatic.com.au" rel="dns-prefetch"/>
#   <link href="//rimh2.domainstatic.com.au" rel="dns-prefetch"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="#0ea800" name="theme-color"/>
#   <link href="https://s.domainstatic.com.au/domain/54.png" rel="apple-touch-icon-precomposed"/>
#   <link href="https://s.domainstatic.com.au/domain/72.png" rel="apple-touch-icon-precomposed"/>
#   <link href="https://s.domainstatic.com.au/domain/114.png" rel="apple-touch-icon-precomposed"/>
#   <link href="https://s.domainstatic.com.au/domain/144.png" rel="apple-touch-icon-precomposed"/>
#   <link href="https://s.domainstatic.com.au/domain/favicon.ico" rel="shortcut icon"/>
#   <link href="https://s.domainstatic.com.au/design-tokens/latest/css/domain.css" rel="stylesheet"/>
#   <link as="font" crossorigin="true" href="https://s.domainstatic.com.au/content/fe-static/@domain-group/fe-brary/static/fonts/bolton/F37Bolton-Regular.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="true" href="https://s.domainstatic.com.au/content/fe-static/@domain-group/fe-brary/static/fonts/bolton/F37Bolton-Bold.woff2" rel="preload" type="font/woff2"/>
#   <link href="/manifest.json" rel="manifest"/>
#   <meta content="#0ea800" name="theme-color"/>
#   <noscript>
#    <style>
#     .expander__gradient { display: none !important; }
#       .expander__wrapper { max-height: none !important; }
#       .expander-content { height: auto !important; }
#    </style>
#   </noscript>
#   <script async="" defer="" src="https://accounts.google.com/gsi/client">
#   </script>
#   <noscript data-n-css="">
#   </noscript>
#   <script defer="" nomodule="" src="https://s.domainstatic.com.au/fe-server-search-listings/master-6261/_next/static/chunks/polyfills-c67a75d1b6f99dc8.js">
#   </script>
#   <script defer="" src="https://s.domainstatic.com.au/fe-server-search-listings/master-6261/_next/static/chunks/webpack-455f579777b6a3e3.js">
#   </script>
#   <script defer="" src="https://s.domainstatic.com.au/fe-server-search-listings/master-6261/_next/static/chunks/framework-bb5c596eafb42b22.js">
#   </script>
#   <script defer="" src="https://s.domainstatic.com.au/fe-server-search-listings/master-6261/_next/static/chunks/main-8792140196772a8e.js">
#   </script>
#   <script defer="" src="https://s.domainstatic.com.au/fe-server-search-listings/master-6261/_next/static/chunks/pages/_app-4177f0ff409a05a7.js">
#   </script>
#   <script defer="" src="https://s.domainstatic.com.au/fe-server-search-listings/master-6261/_next/static/chunks/c0d53ec4-e4064371cbf17ce8.js">
#   </script>
#   <script defer="" src="https://s.domainstatic.com.au/fe-server-search-listings/master-6261/_next/static/chunks/05d954cf-c4a4ae8b3d8b9e7f.js">
#   </script>
#   <script defer="" src="https://s.domainstatic.com.au/fe-server-search-listings/master-6261/_next/static/chunks/621ca4e0-7a27cc7295cab381.js">
#   </script>
#   <script defer="" src="https://s.domainstatic.com.au/fe-server-search-listings/master-6261/_next/static/chunks/487-074080e2de018480.js">
#   </script>
#   <script defer="" src="https://s.domainstatic.com.au/fe-server-search-listings/master-6261/_next/static/chunks/811-a98688835aba1d6c.js">
#   </script>
#   <script defer="" src="https://s.domainstatic.com.au/fe-server-search-listings/master-6261/_next/static/chunks/660-1b8031f009a68251.js">
#   </script>
#   <script defer="" src="https://s.domainstatic.com.au/fe-server-search-listings/master-6261/_next/static/chunks/813-a564b2f701470819.js">
#   </script>
#   <script defer="" src="https://s.domainstatic.com.au/fe-server-search-listings/master-6261/_next/static/chunks/606-70361de6c65426f9.js">
#   </script>
#   <script defer="" src="https://s.domainstatic.com.au/fe-server-search-listings/master-6261/_next/static/chunks/408-7c76b54c56c2080e.js">
#   </script>
#   <script defer="" src="https://s.domainstatic.com.au/fe-server-search-listings/master-6261/_next/static/chunks/386-3194d84a2b71ec9d.js">
#   </script>
#   <script defer="" src="https://s.domainstatic.com.au/fe-server-search-listings/master-6261/_next/static/chunks/pages/listing-details-1041639f73d1e19a.js">
#   </script>
#   <script defer="" src="https://s.domainstatic.com.au/fe-server-search-listings/master-6261/_next/static/cdyZfNtaT-ndAXepOcaAI/_buildManifest.js">
#   </script>
#   <script defer="" src="https://s.domainstatic.com.au/fe-server-search-listings/master-6261/_next/static/cdyZfNtaT-ndAXepOcaAI/_ssgManifest.js">
#   </script>
#   <style data-emotion-css="0 1647809 14bvb6w 1pil8fx 1htgcm6 soiaw8 16q9xmc in3yi3 1ktrj7 92nhrz 3iphef kq1czj 1sz1o9c ayy0g3 a5sdz5 eijyrs 1ksjyp9 1xvzo5j 1rn0l2q 16sh9nl 1b510m5 1d18sav 14pzhpl 1yb5o2f 1y99tdz zdpt2t 1mkb4hf 1ubmefp jrihj8 1x69tlc u3doqj k008qs r1hepj 1f774q1 1ohxmtf kry84i 1i9f8ld b1dmbj dso96h 1mervjy 18kogzx phgf46 tpm5e o44ej6 70qvj9 mob1kv 17heewl 1plbxn8 msy2em bfwnxu lvk3fp 12ts2br i9gxme aeox7o 1mnayj9 15z5ub9 1fxwwk2 70gxn5 1v9ncmt upom2o 1rc2dg 1bzs5ys 403q3d c4nlgs 1gmk1d0 1rcxou4 iqrvhs 98zqy0 4r2lp0 6jrdpz pcc5tv 1f7beg9 9fnvv1 iikheu nf7p82 1fjztun jeyium 1s26z8e 13qoov6 bvqskr e04sm5 9mjt1b pyyome hfv6t1 21om3h tqrkgn jdwnjy 1oc4a4b p1hdku 1ghf5a 2g8bc3 urnqdz 1df9pir xjjik8 1cd0rum s0c94w z5cb3v 1gwgnee v68orn 12ctck7 j7qwjs 11j2nt7 11p64tk 1p4rxlu 1echy3m o8hm0f qrpph4 1azjcl 8yo374 bh4wo8 ml426i xsxs71 w7mtw 1leqk3e 1e4h8p 1oayvlo 1jfnpot 1aahkgc 1n2mv2k rmn0pq e6s3qy 1ejikii v7or7 2ifioa 4bd6g2 n3phri 1pwoa1a 1op0mu2 1lk7kae hou1l6 1d04sp6 7yih9v 1ensggs 159t2o9 17awupb 1g1b5ir h1fb0o 2b0zyx 7a6m7g 1u66hjh 1xb1yes 1hbcpde 19tmy14 1mmffv4 2anoks s4rjyl fpm9y gg4vpm twgrok 17aata3 q473zh 1tpe8dy 164r41r hyxlzm mf9h20 1dtnjt5 ghc6s4 18biwo 1ie6g1l lvv8is 12a1b0h gsqvet 9fxapx dvvls9 1h9anz9 12j1ckg 13od2or o39coc 1bp6yy5 1l0fqcl 1kt5j5d 1e450r1 1v0nat1 iel6rd 4ewd2m vajaaq 1lvolr3 1rcabp 1iyyskk 12k4jkb maj3td 7fqxkk 1ofqig9 19r598r 1wivy4 12fpqlj 9jay18 15ieodi 1h9xr7v yu3fys bq4jj8 8shhfl 6cl4nz juce83 14y7q63 1pn4141 1ua8i65 1hz9l9q 1jqdyix 1fkb39v 6s4w0i kgwx9n keet79 yt9dan urbgr8 1dra2ks yub8l0 xn3w06 yjd8ae 79elbk fgldsh 5d8tra 8o2tce 1vlxv67 1g3iwis 1aszeu9 1t3fbds 1ogmga3 1kx1vw1 1agshq9 1exm8a2 iz8rqi 1bdnm7a 160suvv hhceli uecegc 1bx5ylf s5h158 anqav8 18he1zu ckdcyi 2g7p9b 1hss7u 1xktppr er27os d5e4fw 1eyghyo 1xkf6bf 11opylp ll8m8e 5w5cop 16u8hsx 1ohiqwe 14luiyv 1x99s3g 20k38 1qr51vw 1r3vxqv of3n5h 19vvp6y 1eqgm6m 10se0ru 1jbo6u9 1oz282r 1ruxp1v dxsqis 1nf41fb 148pnmw xl3zjr 1ng06fr 1vel7zb oogxiv i8rtx7 wqrhzo 17s65x 77hcv 1isnb15 bx5tzn 1ij7r2s 1mv10uk 1jmkh0r 1ln6gsy 8atqhb rw5qep l8h8w5 1u8wply 1a43shy 1srjr3j 1p3vy97 1cma4kr 199ul8s 10fm1ku 1ydtjsk 5vlokc 1h87dze ibsnk8 rb7xa0 6xftdw 9f1s3l htn3nq 14hea9r bwdiw1 gkdao9 1ruej2h pori7h 1ymya4c 1duxvxh 1d0l3dm 1ttwaf6 60ltw9 1rfge5p 1wlfg8q 1ngc9ds 1qcqfk4 1q9pxre 13v3rg8 1no9ncl 9yy3nb 8iqr65 skoo0e fkzd4j mlseai 170a2ks 1ks7ds9 csimue 12uo2x5 1jhlvvv 1ejmyle 5zyjdm xnw4nx xydsc 11o9nv2 hx63rl w7rvs5 1a4uoma uq60t0 8wsqbr cyompj kgvt2c 126m299 35ezg3 1cubz1s 8kzdzc 1nq9f9j dpwygs okm1nw 1ng3iwm 3jnhoe 1rhscyc 1xflzjh ea78td 1512tp3 tujexh 1wgvd33 5m45y6 1f8w66e gb0zp5 5y2uu q4d8xy sseo8 f910hf 5githi 1jlvtcy 255y13 1sc1xv6 i6vafo 1kq0p4h sy8qz5 1elgojh tzpe5o 1wl00i5 ayspv3 w759zf lwnzas 1fjxts5 8rx3an 1vnk65d u7el27 zrn8k3 1sn2wgq 1d6ufic 12v79fl afo4em 2p0hlf 8zoq7r czifjo 1k2q731 oye6n6 u56ktn ohdrtb cpfywy 1foors3 10acnyi cb7ppi 15rtbd2 1a2wxca 1a8ltdz k3a5lf fwi4fn 19rerkd 1apz8id 1saunam dzner9 1p52ar5 fup5wb g0adsl 1m4mvav 1l4w6pd 1tjbjx0 1qb9w0p 1ocyb6q 41mpec 1cfk4qn 1fibop0 r5boi6 1ply6nu zrg2js 1hk0lw">
#    .css-1647809{margin-top:18px;}@font-face{font-family:'Domain';src:url('https://s.domainstatic.com.au/content/fe-static/@domain-group/fe-brary/static/fonts/domain-icons/Domain_v2.eot');src:url('https://s.domainstatic.com.au/content/fe-static/@domain-group/fe-brary/static/fonts/domain-icons/Domain_v2.eot?#iefix') format('embedded-opentype'),url('https://s.domainstatic.com.au/content/fe-static/@domain-group/fe-brary/static/fonts/domain-icons/Domain_v2.ttf') format('truetype'),url('https://s.domainstatic.com.au/content/fe-static/@domain-group/fe-brary/static/fonts/domain-icons/Domain_v2.woff') format('woff'),url('https://s.domainstatic.com.au/content/fe-static/@domain-group/fe-brary/static/fonts/domain-icons/Domain_v2.svg') format('svg');font-weight:normal;font-style:normal;}@font-face{font-family:'F37 Bolton';font-style:normal;font-weight:normal;src:url('https://s.domainstatic.com.au/content/fe-static/@domain-group/fe-brary/static/fonts/bolton/F37Bolton-Regular.woff2') format('woff2'),url('https://s.domainstatic.com.au/content/fe-static/@domain-group/fe-brary/static/fonts/bolton/F37Bolton-Regular.woff') format('woff');font-display:swap;}@font-face{font-family:'F37 Bolton';font-style:italic;font-weight:normal;src:url('https://s.domainstatic.com.au/content/fe-static/@domain-group/fe-brary/static/fonts/bolton/F37Bolton-Italic.woff2') format('woff2'),url('https://s.domainstatic.com.au/content/fe-static/@domain-group/fe-brary/static/fonts/bolton/F37Bolton-Bold.woff') format('woff');font-display:swap;}@font-face{font-family:'F37 Bolton';font-style:normal;font-weight:bold;src:url('https://s.domainstatic.com.au/content/fe-static/@domain-group/fe-brary/static/fonts/bolton/F37Bolton-Bold.woff2') format('woff2'),url('https://s.domainstatic.com.au/content/fe-static/@domain-group/fe-brary/static/fonts/bolton/F37Bolton-Bold.woff') format('woff');font-display:swap;}@font-face{font-family:'F37 Bolton';font-style:italic;font-weight:bold;src:url('https://s.domainstatic.com.au/content/fe-static/@domain-group/fe-brary/static/fonts/bolton/F37Bolton-BoldItalic.woff2') format('woff2'),url('https://s.domainstatic.com.au/content/fe-static/@domain-group/fe-brary/static/fonts/bolton/F37Bolton-BoldItalic.woff') format('woff');font-display:swap;}html,body{margin:0;padding:0;border:0;vertical-align:baseline;}div,span,applet,object,iframe,h1,h2,h3,h4,h5,h6,p,blockquote,pre,a,abbr,acronym,address,big,cite,code,del,dfn,em,img,ins,kbd,q,s,samp,small,strike,strong,sub,sup,tt,var,b,u,i,center,dl,dt,dd,ol,ul,li,fieldset,form,label,legend,table,caption,tbody,tfoot,thead,tr,th,td,article,aside,canvas,details,embed,figure,figcaption,footer,header,hgroup,menu,nav,output,ruby,section,summary,time,mark,audio,video{margin:0;padding:0;border:0;font-size:100%;font:inherit;vertical-align:baseline;}input,button,select,optgroup,textarea{margin:0;font-family:inherit;}article,aside,details,figcaption,figure,footer,header,hgroup,menu,nav,section{display:block;}ol,ul{list-style:none;}blockquote,q{quotes:none;}blockquote:before,blockquote:after,q:before,q:after{content:'';content:none;}table{border-collapse:collapse;border-spacing:0;}html{box-sizing:border-box;}*,*::before,*::after{box-sizing:inherit;}body{background-color:var(--color-neutral-surface-default,#FFFFFF);font-family:var(--type-body-family,'F37 Bolton',Helvetica,Arial,sans-serif);font-size:var(--type-body-size,16px);line-height:var(--type-body-line-height,24px);font-weight:var(--type-body-weight,400);text-transform:none;color:var(--color-neutral-heavy-default,#3C475B);-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;-webkit-text-size-adjust:100%;text-size-adjust:100%;-webkit-text-size-adjust:100%;}@-webkit-keyframes spin{from{-webkit-transform:rotate(0deg);-ms-transform:rotate(0deg);transform:rotate(0deg);}to{-webkit-transform:rotate(359deg);-ms-transform:rotate(359deg);transform:rotate(359deg);}}@keyframes spin{from{-webkit-transform:rotate(0deg);-ms-transform:rotate(0deg);transform:rotate(0deg);} ...
#   </style>
#  </head>
#  <body>
#   <div data-reactroot="" id="__next">
#    <div>
#     <noscript>
#      <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-M3HVG4" style="display:none;visibility:hidden" title="Google Tag Manager No Script" width="0">
#      </iframe>
#     </noscript>
#     <a class="css-1htgcm6" data-testid="skip-link" href="#skip-link-target" rel="nofollow">
#      Skip to content
#      <span class="css-soiaw8">
#       <span class="css-16q9xmc">
#        .
#       </span>
#      </span>
#      Contact Support
#      <span class="css-in3yi3">
#       1300 799 109
#      </span>
#     </a>
#     <div class="css-1ktrj7">
#      <div class="listing-details__root">
#       <div class="css-92nhrz">
#        <div aria-hidden="false" class="css-3iphef" data-adbridg-ad-class="adb-slp-top" data-testid="adb-slp-top" focusable="true" id="adb-slp-top">
#        </div>
#       </div>
#       <header class="header css-kq1czj" role="banner">
#        <div class="css-ayy0g3" data-testid="mobile-nav-body__overlay">
#        </div>
#        <section class="css-a5sdz5">
#         <div class="css-eijyrs">
#          <div class="css-1ksjyp9">
#           <div class="css-1xvzo5j">
#            <svg viewbox="0 0 81 18" xmlns="http://www.w3.org/2000/svg">
#             <g>
#              <polygon class="css-1rn0l2q" points="18.8,8.9 20,8.1 21.2,8.9 21.2,12.4 22.2,12.4 22.2,8.9 23.4,8.1 24.6,8.9 24.6,12.4 25.6,12.4 25.6,8.4 23.4,7 21.7,8.1 20,7 18.8,7.8 18.8,7.3 17.8,7.3 17.8,12.4 18.8,12.4">
#              </polygon>
#              <path class="css-1rn0l2q" d="M10.5,11.4c0.6-0.6,1-1.5,1-2.4v0c0-0.9-0.4-1.8-1-2.4C9.9,6,9,5.6,7.9,5.6l-2.4,0v6.8h2.4 C9,12.4,9.9,12.1,10.5,11.4z M6.6,6.6h1.4c0.8,0,1.4,0.2,1.9,0.7c0.4,0.4,0.7,1.1,0.7,1.7v0c0,1.4-1.1,2.4-2.6,2.4H6.6L6.6,6.6z">
#              </path>
#              <circle class="css-1rn0l2q" cx="32.1" cy="5.9" r="0.7">
#              </circle>
#              <path class="css-1rn0l2q" d="M34.5,9.5c0-0.8,0.5-1.4,1.3-1.4c0.7,0,1.2,0.5,1.2,1.3v3h1V9.3c0-1.3-0.8-2.1-1.9-2.1c-0.6,0-1.1,0.2-1.5,0.6 V7.3h-1v5.1h1V9.5z">
#              </path>
#              <rect class="css-1rn0l2q" height="5.1" width="1" x="31.6" y="7.3">
#              </rect>
#              <path class="css-1rn0l2q" d="M14.6,12.5L14.6,12.5c1.5,0,2.6-1.2,2.6-2.7v0c0-0.7-0.3-1.4-0.7-1.9c-0.5-0.5-1.1-0.8-1.9-0.8 c-0.7,0-1.4,0.3-1.9,0.8C12.3,8.5,12,9.2,12,9.9v0C12,11.4,13.2,12.5,14.6,12.5z M13,9.9c0-1,0.7-1.7,1.6-1.7 c0.9,0,1.6,0.8,1.6,1.7v0c0,0.5-0.2,0.9-0.4,1.2c-0.3,0.3-0.7,0.5-1.1,0.5C13.7,11.6,13,10.8,13,9.9L13,9.9z">
#              </path>
#              <path class="css-1rn0l2q" d="M28.1,12.5c0.7,0,1.2-0.3,1.6-0.6v0.5h1V9.3c0-0.6-0.2-1.2-0.5-1.5c-0.4-0.4-0.9-0.6-1.6-0.6 c-0.6,0-1.2,0.1-1.8,0.4l-0.1,0.1l0.3,0.9l0.1-0.1c0.5-0.2,0.9-0.3,1.4-0.3c0.8,0,1.2,0.4,1.3,1.1c-0.4-0.1-0.8-0.2-1.3-0.2 c-0.6,0-1.2,0.1-1.5,0.4c-0.4,0.3-0.6,0.7-0.6,1.3v0C26.2,12,27.2,12.5,28.1,12.5z M27.2,10.8c0-0.5,0.5-0.8,1.2-0.8 c0.5,0,0.9,0.1,1.2,0.2v0.3c0,0.3-0.1,0.6-0.4,0.8c-0.3,0.2-0.6,0.3-1,0.3C27.8,11.7,27.2,11.4,27.2,10.8L27.2,10.8z">
#              </path>
#              <rect class="st1" height="0.5" transform="matrix(-2.034506e-06 1 -1 -2.034506e-06 89.7573 -71.7571)" width="18" x="71.8" y="8.7">
#              </rect>
#              <g>
#               <path class="css-1rn0l2q" d="M58.8,8.2c-0.7,0-1.2,0.4-1.3,1.1H60C60,8.6,59.5,8.2,58.8,8.2z">
#               </path>
#               <path class="css-1rn0l2q" d="M72.1,10.9c0,0.4,0.4,0.6,0.9,0.6c0.8,0,1.2-0.4,1.2-1.1v-0.3H74C72.1,10.1,72.1,10.7,72.1,10.9z">
#               </path>
#               <path class="css-1rn0l2q" d="M80,0H46.8h-1.1h-2.8H1H0h0v1h0L0,17l0,0v1h1h41.9h2.8h1.1H80h1V0H80z M50.2,7.2c0.8,0,1.3,0.3,1.6,0.9 c0.4-0.6,0.9-0.9,1.7-0.9c0.8,0,1.8,0.4,1.8,2.2l0,3H54l0-2.9c0-0.8-0.3-1.1-0.9-1.1c-0.5,0-1.1,0.3-1.1,1.3l0,2.8h-1.3l0-3 c0-0.8-0.5-1-0.8-1c-0.7,0-1.1,0.5-1.1,1.3v2.8h-1.3V7.3h1.3V8C49,7.5,49.6,7.2,50.2,7.2z M58.8,11.5c0.5,0,1-0.2,1.3-0.7l0,0 l0.9,0.7l0,0c-0.5,0.7-1.3,1-2.2,1c-1.6,0-2.8-1.1-2.8-2.7s1.2-2.7,2.8-2.7c1.5,0,2.4,1.1,2.4,2.8v0.4h-3.8 C57.6,11,58.1,11.5,58.8,11.5z M64.5,12.5c-1.5,0-2.5-1.1-2.5-2.7c0-1.5,1-2.7,2.5-2.7c0.7,0,1.3,0.3,1.7,0.8V4.8h1.3v7.6h-1.3 v-0.7C65.9,12.2,65.3,12.5,64.5,12.5z M69.3,6.4c-0.5,0-0.8-0.4-0.8-0.8c0-0.4,0.4-0.8,0.8-0.8c0.5,0,0.8,0.3,0.8,0.8 C70.2,6.1,69.8,6.4,69.3,6.4z M70,12.4h-1.3l0-5.1H70L70,12.4z M74.3,12.4l0-0.7c-0.3,0.5-0.9,0.8-1.6,0.8c-0.5,0-0.9-0.1-1.3-0.4 c-0.4-0.3-0.6-0.7-0.6-1.2c0-1.6,1.7-1.8,3.2-1.8h0.3V9.1c0-0.6-0.4-0.9-1.1-0.9c-0.5,0-1,0.2-1.3,0.5l0,0L71.1,8l0,0 c0.5-0.5,1.3-0.8,2.2-0.8c2.2,0,2.2,1.6,2.2,2.3l0,2.9H74.3z M2,16V2h40v14H2z">
#               </path>
#               <path class="css-1rn0l2q" d="M64.8,8.4c-0.9,0-1.5,0.8-1.5,1.5c0,0.7,0.5,1.5,1.5,1.5c0.9,0,1.5-0.8,1.5-1.5C66.2,9.1,65.7,8.4,64.8,8.4z">
#               </path>
#              </g>
#             </g>
#            </svg>
#           </div>
#          </div>
#          <a class="css-16sh9nl" href="https://www.allhomes.com.au/">
#           <!-- -->
#           Allhomes
#           <!-- -->
#          </a>
#          <a class="css-16sh9nl" href="https://www.commercialrealestate.com.au/">
#           <!-- -->
#           Commercial Real Estate
#           <!-- -->
#          </a>
#         </div>
#        </section>
#        <div class="css-1b510m5">
#         <div class="css-1d18sav" data-testid="header__toolbar-inner">
#          <button class="css-14pzhpl" data-testid="mobile-nav__main-toggle" type="button">
#           <span class="css-16q9xmc">
#            Navigation
#           </span>
#           <span class="css-1yb5o2f">
#           </span>
#          </button>
#          <a class="css-1y99tdz" href="https://www.domain.com.au/" title="Domain homepage">
#           <div class="domain-logo__wrapper" id="domain-logo-wrapper">
#            <svg viewbox="0 0 97 22" xmlns="http://www.w3.org/2000/svg">
#             <path class="domain-logo__svg-icon" d="M72.51 18.27v-7c0-4.28-2.63-5.51-6-5.51-3.62 0-6 1.89-6 5h2.79c0-1.55 1-2.42 3.29-2.42 2.49 0 3.21 1.08 3.21 2.09 0 .84-.18 1.29-1.65 1.56l-3.32.63c-2.91.54-5 1.86-5 4.91 0 2.82 2.34 4.47 5 4.47A6.15 6.15 0 0070 19.62V20a1.54 1.54 0 001.41 1.66 1.37 1.37 0 00.35 0H74v-2.34h-.36c-.86 0-1.13-.32-1.13-1.05zm-2.66-2.69c0 2.09-1.77 3.89-4.53 3.89-1.64 0-2.54-.84-2.54-2.22s1-2 3.11-2.48l2.67-.57a4.21 4.21 0 001.29-.45zM7 .12H0V21.6h6.71c6.62 0 11-4.53 11-10.76C17.7 3.83 12.67.12 7 .12zm-.29 18.81H2.94V2.82h3.47c4.91 0 8.33 2.66 8.33 8s-3.69 8.11-8.03 8.11zM75.66 6.15h2.68V21.6h-2.68zM87.87 5.75a5.53 5.53 0 00-4.42 2v-1.6h-2.68V21.6h2.68v-9.75a3.73 3.73 0 016-2.95 4 4 0 01.48.44l.07.09a3.68 3.68 0 01.89 2.41v9.76h2.68v-9.53c.02-3.98-2.1-6.32-5.7-6.32zM77 0a1.81 1.81 0 101.82 1.8A1.82 1.82 0 0077 0zM52.18 5.48L47.4 8.73l-4.8-3.25-3.45 2.33V6.15h-2.68V21.6h2.68V11.06l3.45-2.34 3.43 2.34V21.6h2.68V11.06l3.47-2.34 3.46 2.34V21.6h2.68V9.62l-6.14-4.14zM27 5.74a7.93 7.93 0 00-8.08 7.78v.36a7.91 7.91 0 007.7 8.12H27a7.91 7.91 0 008-7.82v-.3a7.93 7.93 0 00-7.72-8.14zm0 13.54a5.41 5.41 0 115.4-5.42 5.42 5.42 0 01-5.4 5.42z" fill="#FEFEFE" fill-rule="evenodd">
#             </path>
#            </svg>
#           </div>
#          </a>
#          <div class="css-zdpt2t">
#           <button class="css-1mkb4hf" data-testid="mobile-nav__secondary-toggle" type="button">
#            Log in
#            <span class="css-16q9xmc">
#             Account
#            </span>
#           </button>
#          </div>
#          <nav class="css-1ubmefp" role="navigation">
#           <div class="css-jrihj8">
#            <div class="css-1x69tlc">
#             <button class="css-u3doqj" data-testid="header-button-login" data-type="login" type="button">
#              Log in
#             </button>
#            </div>
#           </div>
#           <ul class="css-k008qs">
#            <li class="css-r1hepj" data-testid="header-menu-desktop-option">
#             <a class="css-1f774q1" href="#">
#              Find a Property
#              <div class="css-1ohxmtf">
#               <svg aria-hidden="true" class="domain-icon css-kry84i" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
#                <path d="M4 9.24795L12 17.3334L20 9.24795L18.5541 8.00004L12 14.6239L5.44589 8.00004L4 9.24795Z" fill="currentColor">
#                </path>
#               </svg>
#              </div>
#             </a>
#            </li>
#            <li class="css-r1hepj" data-testid="header-menu-desktop-option">
#             <a class="css-1f774q1" href="#">
#              Research
#              <div class="css-1ohxmtf">
#               <svg aria-hidden="true" class="domain-icon css-kry84i" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
#                <path d="M4 9.24795L12 17.3334L20 9.24795L18.5541 8.00004L12 14.6239L5.44589 8.00004L4 9.24795Z" fill="currentColor">
#                </path>
#               </svg>
#              </div>
#             </a>
#            </li>
#            <li class="css-r1hepj" data-testid="header-menu-desktop-option">
#             <a class="css-1i9f8ld" href="https://www.domain.com.au/real-estate-agents/">
#              Find Agents
#             </a>
#            </li>
#            <li class="css-r1hepj" data-testid="header-menu-desktop-option">
#             <a class="css-1f774q1" href="#">
#              For Owners
#              <div class="css-1ohxmtf">
#               <svg aria-hidden="true" class="domain-icon css-kry84i" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
#                <path d="M4 9.24795L12 17.3334L20 9.24795L18.5541 8.00004L12 14.6239L5.44589 8.00004L4 9.24795Z" fill="currentColor">
#                </path>
#               </svg>
#              </div>
#             </a>
#            </li>
#            <li class="css-r1hepj" data-testid="header-menu-desktop-option">
#             <a class="css-1f774q1" href="#">
#              News
#              <div class="css-1ohxmtf">
#               <svg aria-hidden="true" class="domain-icon css-kry84i" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
#                <path d="M4 9.24795L12 17.3334L20 9.24795L18.5541 8.00004L12 14.6239L5.44589 8.00004L4 9.24795Z" fill="currentColor">
#                </path>
#               </svg>
#              </div>
#             </a>
#            </li>
#            <li class="css-r1hepj" data-testid="header-menu-desktop-option">
#             <a class="css-1i9f8ld" href="https://www.commercialrealestate.com.au/">
#              Commercial
#             </a>
#            </li>
#           </ul>
#          </nav>
#         </div>
#         <div class="css-b1dmbj" data-testid="header__inner-lower">
#          <div class="css-dso96h">
#           <div class="css-1mervjy">
#            <div class="css-18kogzx">
#             <button class="css-phgf46" data-testid="header__back-button" type="button">
#              <svg aria-hidden="true" class="domain-icon css-kry84i" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
#               <path d="M15.5521 20L7.46667 12L15.5521 4L16.8 5.44589L10.1762 12L16.8 18.5541L15.5521 20Z" fill="currentColor">
#               </path>
#              </svg>
#              <span class="css-tpm5e">
#               For rent in Melbourne
#              </span>
#             </button>
#            </div>
#            <nav aria-label="Breadcrumb" class="css-o44ej6" data-testid="breadcrumbs">
#             <ul class="css-70qvj9">
#              <li class="css-mob1kv" data-testid="breadcrumbs__crumb">
#               <a alt="Home" class="css-17heewl" href="https://www.domain.com.au/">
#                <span class="css-0">
#                 Home
#                </span>
#               </a>
#              </li>
#              <li class="css-mob1kv" data-testid="breadcrumbs__crumb">
#               <a alt="Rent" class="css-17heewl" href="/rent/">
#                <svg aria-hidden="true" class="domain-icon css-kry84i" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
#                 <path d="M8.71457 20L16.8 12L8.71457 4L7.46665 5.44589L14.0905 12L7.46665 18.5541L8.71457 20Z" fill="currentColor">
#                 </path>
#                </svg>
#                <span class="css-0">
#                 Rent
#                </span>
#               </a>
#              </li>
#              <li class="css-mob1kv" data-testid="breadcrumbs__crumb">
#               <a alt="VIC" class="css-17heewl" href="/rent/vic/">
#                <svg aria-hidden="true" class="domain-icon css-kry84i" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
#                 <path d="M8.71457 20L16.8 12L8.71457 4L7.46665 5.44589L14.0905 12L7.46665 18.5541L8.71457 20Z" fill="currentColor">
#                 </path>
#                </svg>
#                <span class="css-0">
#                 VIC
#                </span>
#               </a>
#              </li>
#              <li class="css-mob1kv" data-testid="breadcrumbs__crumb">
#               <a alt="Melbourne" class="css-17heewl" href="/rent/melbourne-vic-3000/">
#                <svg aria-hidden="true" class="domain-icon css-kry84i" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
#                 <path d="M8.71457 20L16.8 12L8.71457 4L7.46665 5.44589L14.0905 12L7.46665 18.5541L8.71457 20Z" fill="currentColor">
#                 </path>
#                </svg>
#                <span class="css-0">
#                 Melbourne
#                </span>
#               </a>
#              </li>
#              <li class="css-mob1kv" data-testid="breadcrumbs__crumb">
#               <a alt="Apartments" class="css-17heewl" href="/rent/melbourne-vic-3000/apartment-unit-flat/">
#                <svg aria-hidden="true" class="domain-icon css-kry84i" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
#                 <path d="M8.71457 20L16.8 12L8.71457 4L7.46665 5.44589L14.0905 12L7.46665 18.5541L8.71457 20Z" fill="currentColor">
#                 </path>
#                </svg>
#                <span class="css-0">
#                 Apartments
#                </span>
#               </a>
#              </li>
#              <li class="css-mob1kv" data-testid="breadcrumbs__crumb">
#               <a alt="0-Bedroom" class="css-17heewl" href="/rent/melbourne-vic-3000/apartment-unit-flat/0-bedroom/">
#                <svg aria-hidden="true" class="domain-icon css-kry84i" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
#                 <path d="M8.71457 20L16.8 12L8.71457 4L7.46665 5.44589L14.0905 12L7.46665 18.5541L8.71457 20Z" fill="currentColor">
#                 </path>
#                </svg>
#                <span class="css-0">
#                 0-Bedroom
#                </span>
#               </a>
#              </li>
#              <li class="css-mob1kv" data-testid="breadcrumbs__crumb">
#               <span class="css-1plbxn8">
#                <svg aria-hidden="true" class="domain-icon css-kry84i" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
#                 <path d="M8.71457 20L16.8 12L8.71457 4L7.46665 5.44589L14.0905 12L7.46665 18.5541L8.71457 20Z" fill="currentColor">
#                 </path>
#                </svg>
#                <span class="css-0">
#                 508/408 Lonsdale Street, Melbourne VIC 3000
#                </span>
#               </span>
#              </li>
#             </ul>
#            </nav>
#           </div>
#          </div>
#         </div>
#        </div>
#        <nav class="css-msy2em" data-testid="mobile-nav">
#         <ul class="css-bfwnxu">
#          <li class="css-lvk3fp" data-testid="header-menu-mobile-option">
#           <button class="css-12ts2br" type="button">
#            <span class="css-i9gxme" data-testid="mobile-nav__heading-copy">
#             Find a Property
#            </span>
#            <svg aria-hidden="true" class="domain-icon css-kry84i" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
#             <path d="M4 9.24795L12 17.3334L20 9.24795L18.5541 8.00004L12 14.6239L5.44589 8.00004L4 9.24795Z" fill="currentColor">
#             </path>
#            </svg>
#           </button>
#           <div class="noscript-expander-wrapper css-aeox7o" data-testid="expander-wrapper" id="collapsible-panel" style="max-height:0px;overflow:hidden">
#            <div class="noscript-expander-content css-1mnayj9">
#             <div>
#              <ul class="css-15z5ub9" hidden="">
#               <li class="css-1fxwwk2" data-testid="mobile-nav__item">
#                <a class="css-70gxn5" href="https://www.domain.com.au/" target="_self">
#                 <span class="css-1v9ncmt">
#                  Buy
#                 </span>
#                </a>
#               </li>
#               <li class="css-1fxwwk2" data-testid="mobile-nav__item">
#                <a class="css-70gxn5" href="https://www.domain.com.au/?mode=rent" target="_self">
#                 <span class="css-1v9ncmt">
#                  Rent
#                 </span>
#                </a>
#               </li>
#               <li class="css-1fxwwk2" data-testid="mobile-nav__item">
#                <a class="css-70gxn5" href="https://www.domain.com.au/house-and-land" target="_self">
#                 <span class="css-1v9ncmt">
#                  House &amp; Land
#                 </span>
#                </a>
#               </li>
#               <li class="css-1fxwwk2" data-testid="mobile-nav__item">
#                <a class="css-70gxn5" href="https://www.domain.com.au/new-homes" target="_self">
#                 <span class="css-1v9ncmt">
#                  New Homes
#                 </span>
#                </a>
#               </li>
#               <li class="css-1fxwwk2" data-testid="mobile-nav__item">
#                <a class="css-70gxn5" href="https://www.domain.com.au/rural" target="_self">
#                 <span class="css-1v9ncmt">
#                  Rural
#                 </span>
#                </a>
#               </li>
#               <li class="css-1fxwwk2" data-testid="mobile-nav__item">
#                <a class="css-70gxn5" href="https://www.domain.com.au/share/" target="_self">
#                 <span class="css-1v9ncmt">
#                  Share
#                 </span>
#                </a>
#               </li>
#               <li class="css-1fxwwk2" data-testid="mobile-nav__item">
#                <a class="css-70gxn5" href="https://www.domain.com.au/schools" target="_self">
#                 <span class="css-1v9ncmt">
#                  Search by school
#                 </span>
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#           </div>
#          </li>
#          <li class="css-lvk3fp" data-testid="header-menu-mobile-option">
#           <button class="css-12ts2br" type="button">
#            <span class="css-i9gxme" data-testid="mobile-nav__heading-copy">
#             Research
#            </span>
#            <svg aria-hidden="true" class="domain-icon css-kry84i" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
#             <path d="M4 9.24795L12 17.3334L20 9.24795L18.5541 8.00004L12 14.6239L5.44589 8.00004L4 9.24795Z" fill="currentColor">
#             </path>
#            </svg>
#           </button>
#           <div class="noscript-expander-wrapper css-aeox7o" data-testid="expander-wrapper" id="collapsible-panel" style="max-height:0px;overflow:hidden">
#            <div class="noscript-expander-content css-1mnayj9">
#             <div>
#              <div class="css-15z5ub9" hidden="">
#               <div class="css-upom2o">
#                Property Market Insights
#               </div>
#               <ul>
#                <li class="css-1fxwwk2" data-testid="mobile-nav__item">
#                 <a class="css-70gxn5" href="https://www.domain.com.au/property-profile" target="_self">
#                  <span class="css-1v9ncmt">
#                   Property Price Estimates
#                  </span>
#                 </a>
#                </li>
#                <li class="css-1fxwwk2" data-testid="mobile-nav__item">
#                 <a class="css-70gxn5" href="https://www.domain.com.au/suburb-profile/" target="_self">
#                  <span class="css-1v9ncmt">
#                   Suburb Profiles
#                  </span>
#                 </a>
#                </li>
#                <li class="css-1fxwwk2" data-testid="mobile-nav__item">
#                 <a class="css-70gxn5" href="https://www.domain.com.au/research/" target="_self">
#                  <span class="css-1v9ncmt">
#                   Property Market Analysis
#                  </span>
#                 </a>
#                </li>
#                <li class="css-1fxwwk2" data-testid="mobile-nav__item">
#                 <a class="css-70gxn5" href="https://www.domain.com.au/auction-results/" target="_self">
#                  <span class="css-1v9ncmt">
#                   Auction Results
#                  </span>
#                 </a>
#                </li>
#                <li class="css-1fxwwk2" data-testid="mobile-nav__item">
#                 <a class="css-70gxn5" href="https://www.domain.com.au/?mode=sold" target="_self">
#                  <span class="css-1v9ncmt">
#                   Sold Properties
#                  </span>
#                 </a>
#                </li>
#                <li class="css-1fxwwk2" data-testid="mobile-nav__item">
#                 <a class="css-70gxn5" href="https://www.domain.com.au/afford-to-buy/" target="_self">
#                  <span class="css-1v9ncmt">
#                   Find Affordable Suburbs
#                  </span>
#                 </a>
#                </li>
#               </ul>
#               <div class="css-upom2o">
#                Guides
#               </div>
#               <ul>
#                <li class="css-1fxwwk2" data-testid="mobile-nav__item">
#                 <a class="css-70gxn5" href="https://www.domain.com.au/advice/" target="_self">
#                  <span class="css-1v9ncmt">
#                   Advice
#                  </span>
#                 </a>
#                </li>
#                <li class="css-1fxwwk2" data-testid="mobile-nav__item">
#                 <a class="css-70gxn5" href="https://www.domain.com.au/advice/buying/" target="_self">
#                  <span class="css-1v9ncmt">
#                   Buying
#                  </span>
#                 </a>
#                </li>
#                <li class="css-1fxwwk2" data-testid="mobile-nav__item">
#                 <a class="css-70gxn5" href="https://www.domain.com.au/advice/investing/" target="_self">
#                  <span class="css-1v9ncmt">
#                   Investing
#                  </span>
#                 </a>
#                </li>
#                <li class="css-1fxwwk2" data-testid="mobile-nav__item">
#                 <a class="css-70gxn5" href="https://www.domain.com.au/advice/renting/" target="_self">
#                  <span class="css-1v9ncmt">
#                   Renting
#                  </span>
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </div>
#            </div>
#           </div>
#          </li>
#          <li class="css-1rc2dg" data-testid="mobile-nav__item">
#           <a class="css-1bzs5ys" data-testid="mobile-nav__anchor" href="https://www.domain.com.au/real-estate-agents/">
#            <span class="css-i9gxme" data-testid="mobile-nav__heading-copy">
#             Find Agents
#            </span>
#           </a>
#          </li>
#          <li class="css-lvk3fp" data-testid="header-menu-mobile-option">
#           <button class="css-12ts2br" type="button">
# ...
#              Terms of Service
#             </a>
#             <!-- -->
#             apply.
#            </p>
#           </div>
#           <div class="css-1l4w6pd">
#            <ul class="css-k008qs">
#             <li class="css-zrg2js">
#              <a aria-label="Facebook" class="css-1hk0lw" href="https://www.facebook.com/domain.com.au/">
#               <span class="css-41mpec">
#                <svg aria-hidden="true" class="domain-icon css-jeyium" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
#                 <path clip-rule="evenodd" d="M13.506 6.617V8.006H17.5L17.124 11.999H13.498V22H9.51V11.999H6.5V8.006H9.51V6.198C9.51 4.558 10.102 2 13.649 2L17.5 2.012V5.655H14.42C14.042 5.655 13.506 5.838 13.506 6.617Z" fill="currentColor" fill-rule="evenodd">
#                 </path>
#                </svg>
#               </span>
#               <span class="css-1s26z8e">
#                Facebook
#               </span>
#              </a>
#             </li>
#             <li class="css-zrg2js">
#              <a aria-label="Instagram" class="css-1hk0lw" href="https://www.instagram.com/domain.com.au/">
#               <span class="css-41mpec">
#                <svg aria-hidden="true" class="domain-icon css-jeyium" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
#                 <path clip-rule="evenodd" d="M12 15.334C10.159 15.334 8.666 13.841 8.666 12C8.666 10.159 10.159 8.666 12 8.666C13.841 8.666 15.334 10.159 15.334 12C15.334 13.841 13.841 15.334 12 15.334ZM12 6.865C9.164 6.865 6.865 9.164 6.865 12C6.865 14.836 9.164 17.135 12 17.135C14.836 17.135 17.135 14.836 17.135 12C17.135 9.164 14.836 6.865 12 6.865ZM18.538 6.662C18.538 7.324 18.001 7.862 17.338 7.862C16.676 7.862 16.137 7.324 16.137 6.662C16.137 5.999 16.676 5.461 17.338 5.461C18.001 5.461 18.538 5.999 18.538 6.662ZM20.141 16.041C20.096 17.016 19.932 17.545 19.796 17.897C19.614 18.364 19.397 18.698 19.047 19.048C18.697 19.398 18.363 19.615 17.896 19.796C17.545 19.933 17.016 20.096 16.041 20.141C14.986 20.188 14.67 20.198 12 20.198C9.33 20.198 9.014 20.188 7.959 20.141C6.984 20.096 6.455 19.932 6.103 19.796C5.636 19.614 5.302 19.397 4.952 19.047C4.602 18.697 4.385 18.363 4.204 17.897C4.067 17.545 3.904 17.016 3.859 16.041C3.812 14.986 3.802 14.67 3.802 12C3.802 9.33 3.812 9.014 3.859 7.959C3.904 6.984 4.068 6.455 4.204 6.103C4.386 5.636 4.603 5.302 4.953 4.952C5.303 4.602 5.637 4.385 6.104 4.204C6.455 4.067 6.984 3.904 7.959 3.859C9.014 3.812 9.33 3.802 12 3.802C14.67 3.802 14.986 3.812 16.041 3.859C17.016 3.904 17.545 4.068 17.897 4.204C18.364 4.386 18.698 4.603 19.048 4.953C19.398 5.303 19.615 5.637 19.796 6.104C19.933 6.455 20.096 6.984 20.141 7.959C20.188 9.014 20.198 9.33 20.198 12C20.198 14.67 20.188 14.986 20.141 16.041ZM21.475 5.449C21.22 4.791 20.878 4.234 20.322 3.678C19.766 3.122 19.208 2.78 18.551 2.525C17.914 2.277 17.187 2.108 16.123 2.061C15.056 2.012 14.716 2 12 2V2.001C9.284 2.001 8.944 2.012 7.877 2.059C6.813 2.109 6.085 2.277 5.449 2.526C4.791 2.78 4.234 3.122 3.678 3.678C3.122 4.234 2.78 4.792 2.525 5.449C2.277 6.086 2.108 6.813 2.06 7.877C2.012 8.944 2 9.284 2 12C2 14.716 2.012 15.057 2.06 16.123C2.108 17.188 2.276 17.915 2.525 18.551C2.78 19.209 3.122 19.766 3.678 20.322C4.234 20.878 4.792 21.22 5.449 21.475C6.086 21.723 6.813 21.892 7.877 21.939C8.944 21.988 9.284 22 12 22C14.716 22 15.057 21.988 16.123 21.939C17.187 21.892 17.915 21.723 18.551 21.475C19.209 21.22 19.766 20.878 20.322 20.322C20.878 19.766 21.22 19.208 21.475 18.551C21.723 17.914 21.892 17.188 21.94 16.123C21.988 15.056 22 14.716 22 12C22 9.284 21.988 8.943 21.94 7.877C21.892 6.813 21.724 6.085 21.475 5.449Z" fill="currentColor" fill-rule="evenodd">
#                 </path>
#                </svg>
#               </span>
#               <span class="css-1s26z8e">
#                Instagram
#               </span>
#              </a>
#             </li>
#             <li class="css-zrg2js">
#              <a aria-label="Pinterest" class="css-1hk0lw" href="https://www.pinterest.com.au/domaincomau/">
#               <span class="css-41mpec">
#                <svg aria-hidden="true" class="domain-icon css-jeyium" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
#                 <path clip-rule="evenodd" d="M7.46932 17.508C7.69771 16.574 8.99677 11.248 8.99677 11.248C8.99677 11.248 8.61749 10.515 8.61749 9.43C8.61749 7.728 9.63751 6.457 10.9076 6.457C11.9876 6.457 12.5085 7.241 12.5085 8.182C12.5085 9.232 11.8171 10.802 11.4605 12.258C11.1629 13.478 12.092 14.471 13.3342 14.471C15.583 14.471 17.0991 11.675 17.0991 8.362C17.0991 5.846 15.3474 3.96 12.1592 3.96C8.55755 3.96 6.31288 6.56 6.31288 9.462C6.31288 10.463 6.61878 11.17 7.09727 11.715C7.3174 11.967 7.34634 12.068 7.26779 12.355C7.20992 12.568 7.07971 13.076 7.02493 13.278C6.94639 13.569 6.70249 13.672 6.43069 13.565C4.77303 12.91 4 11.152 4 9.176C4 5.913 6.84408 2 12.4847 2C17.0174 2 20 5.174 20 8.581C20 13.087 17.4112 16.453 13.5946 16.453C12.3121 16.453 11.1071 15.783 10.6937 15.022C10.6937 15.022 10.0054 17.668 9.85971 18.18C9.34505 19.985 7.8331 21.792 7.71632 21.941C7.63467 22.042 7.45278 22.01 7.43315 21.873C7.40111 21.644 7.01666 19.366 7.46932 17.508Z" fill="currentColor" fill-rule="evenodd">
#                 </path>
#                </svg>
#               </span>
#               <span class="css-1s26z8e">
#                Pinterest
#               </span>
#              </a>
#             </li>
#             <li class="css-zrg2js">
#              <a aria-label="Youtube" class="css-1hk0lw" href="https://www.youtube.com/c/domaincomau/">
#               <span class="css-41mpec">
#                <svg aria-hidden="true" class="domain-icon css-jeyium" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
#                 <path clip-rule="evenodd" d="M16.282 12.353L10.64 15.96C10.574 16.004 10.495 16.027 10.417 16.027C10.348 16.027 10.28 16.01 10.217 15.975C10.084 15.902 10 15.762 10 15.609V8.392C10 8.239 10.084 8.098 10.217 8.025C10.35 7.952 10.513 7.958 10.642 8.041L16.282 11.648C16.402 11.726 16.473 11.859 16.473 12C16.473 12.143 16.402 12.276 16.282 12.353ZM18.717 5H5.281C3.469 5 2 6.469 2 8.282V15.717C2 17.531 3.47 19 5.283 19H18.719C20.531 19 22 17.532 22 15.719V8.284C22 6.478 20.523 5 18.717 5Z" fill="currentColor" fill-rule="evenodd">
#                 </path>
#                </svg>
#               </span>
#               <span class="css-1s26z8e">
#                Youtube
#               </span>
#              </a>
#             </li>
#             <li class="css-zrg2js">
#              <a aria-label="Tiktok" class="css-1hk0lw" href="https://www.tiktok.com/@domain.com.au/">
#               <span class="css-41mpec">
#                <svg aria-hidden="true" class="domain-icon css-jeyium" viewbox="0 0 24 24" xmlns="http://www.w3.org/2000/svg">
#                 <path d="M18.6931 5.70502C18.5446 5.62827 18.4001 5.54414 18.26 5.45294C17.8527 5.18367 17.4792 4.86638 17.1477 4.50791C16.3181 3.55875 16.0083 2.59584 15.8942 1.92166H15.8988C15.8034 1.36207 15.8429 1 15.8488 1H12.0705V15.61C12.0705 15.8062 12.0705 16 12.0623 16.1916C12.0623 16.2154 12.06 16.2374 12.0586 16.2631C12.0586 16.2737 12.0586 16.2847 12.0563 16.2957C12.0563 16.2984 12.0563 16.3012 12.0563 16.3039C12.0165 16.8281 11.8484 17.3345 11.567 17.7785C11.2855 18.2225 10.8992 18.5906 10.4421 18.8503C9.96574 19.1213 9.42693 19.2635 8.87883 19.2628C7.11846 19.2628 5.69174 17.8273 5.69174 16.0546C5.69174 14.2818 7.11846 12.8464 8.87883 12.8464C9.21206 12.8461 9.54324 12.8985 9.86008 13.0018L9.86466 9.15472C8.90283 9.03047 7.92569 9.10692 6.99489 9.37922C6.06408 9.65152 5.19981 10.1138 4.4566 10.7368C3.80537 11.3026 3.25788 11.9778 2.83876 12.7318C2.67927 13.0068 2.07751 14.1118 2.00463 15.9052C1.9588 16.9231 2.2645 17.9777 2.41024 18.4135V18.4227C2.5019 18.6793 2.85709 19.5552 3.43594 20.2935C3.9027 20.8858 4.45416 21.406 5.07256 21.8375V21.8284L5.08173 21.8375C6.91085 23.0805 8.93887 22.9989 8.93887 22.9989C9.28994 22.9847 10.466 22.9989 11.8015 22.366C13.2827 21.6643 14.126 20.6189 14.126 20.6189C14.6648 19.9943 15.0932 19.2824 15.3928 18.5139C15.7347 17.6151 15.8488 16.5372 15.8488 16.1064V8.35542C15.8946 8.38292 16.5051 8.78669 16.5051 8.78669C16.5051 8.78669 17.3846 9.35042 18.7568 9.71752C19.7412 9.97876 21.0676 10.0338 21.0676 10.0338V6.28294C20.6029 6.33336 19.6592 6.1867 18.6931 5.70502Z" fill="currentColor">
#                 </path>
#                </svg>
#               </span>
#               <span class="css-1s26z8e">
#                Tiktok
#               </span>
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#        </div>
#       </footer>
#      </div>
#     </div>
#     <div>
#     </div>
#     <script>
#      (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#           (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#           m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#           })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#           ga('create', 'UA-22518123-1', 'auto');
#           ga('require', 'GTM-T6X56MC');
#           ga('set', 'exp', 'shortlist-photo-gallery.0'); // enableShortlistPhotoGallery
#           ga('set', 'exp', 'enableShortlistNotesEditing.0'); // enableShortlistNotesEditing
#           ga('set', 'exp', 'enableUPVExperiment.1'); // enableUPVExperiment
#           ga('set', 'exp', 'enableGraphQLSearch.1'); // enableGraphQLSearch
#           ga('set', 'exp', 'enableGQLOnListingsPage.1'); // enableGQLOnListingsPage
#           ga('set', 'exp', 'enableGraphQLUPVSoldListings.0'); // enableGraphQLUPVSoldListings
#           ga('set', 'exp', 'enableGraphQLFeaturedAgency.0'); // enableGraphQLFeaturedAgency
#           ga('set', 'exp', 'enableGraphQLTopspot.1'); // enableGraphQLTopspot
#           ga('set', 'exp', 'enableGraphQLNewToYou.1'); // enableGraphQLNewToYou
#           ga('set', 'exp', 'enable request floor plan by percentage users.0'); // enableRequestFloorPlanExp
#     </script>
#     <script>
#      (function() {
#           var purl = window.location.href;
#           var url = '//ads.pubmatic.com/AdServer/js/pwt/159133/2355';
#           var profileVersionId = '';
#           if(purl.indexOf('pwtv=')>0){
#             var regexp = /pwtv=(.*?)(&|$)/g;
#             var matches = regexp.exec(purl);
#             if(matches.length >= 2 && matches[1].length > 0){
#               profileVersionId = '/'+matches[1];
#             }
#           }
#           var wtads = document.createElement('script');
#           wtads.async = true;
#           wtads.type = 'text/javascript';
#           wtads.src = url+profileVersionId+'/pwt.js';
#           var node = document.getElementsByTagName('script')[0];
#           node.parentNode.insertBefore(wtads, node);
#         })();
#     </script>
#     <script>
#      var atsScript = document.createElement('script');
#         atsScript.onload = function () {
#           if (window.ats) {
#             window.ats.start({
#               "placementID": 124,
#               "storageType": "localStorage",
#               "detectionType": "scrape",
#               "cssSelectors": [
#                   "input[type=text]",
#                   "input[type=email]"
#               ],
#               "logging": "error"
#             });
#           }
#         };
#         atsScript.src = 'https://ats.rlcdn.com/ats.js';
#         document.body.appendChild(atsScript);
#     </script>
#     <script>
#      (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#         })(window,document,'script','dataLayer','GTM-M3HVG4');
#     </script>
#    </div>
#   </div>
#   <script id="__NEXT_DATA__" type="application/json">
#    {"props":{"pageProps":{"layoutProps":{"title":"508/408 Lonsdale Street, Melbourne VIC 3000 - Apartment For Rent | Domain","description":"View this 1 bathroom rental apartment at 508/408 Lonsdale Street, Melbourne VIC 3000. Available from Friday, 10 February 2023. Contact agent for price.","canonical":"https://www.domain.com.au/508-408-lonsdale-street-melbourne-vic-3000-17166328","metatags":[{"component":"meta","property":"og:title","content":"508/408 Lonsdale Street, Melbourne VIC 3000 - Apartment For Rent | Domain"},{"component":"meta","property":"og:description","content":"View this 1 bathroom rental apartment at 508/408 Lonsdale Street, Melbourne VIC 3000. Available from Friday, 10 February 2023. Contact agent for price."},{"component":"meta","property":"og:type","content":"product"},{"component":"meta","property":"og:site_name","content":"Domain"},{"component":"meta","property":"og:url","content":"https://www.domain.com.au/508-408-lonsdale-street-melbourne-vic-3000-17166328"},{"component":"meta","property":"og:image","content":"https://bucket-api.domain.com.au/v1/bucket/image/17166328_1_1_240818_111609-w2000-h1334"},{"component":"meta","property":"fb:app_id","content":"505328276158724"},{"component":"meta","property":"al:ios:url","content":"domain.com.au://propertyDetails/17166328"},{"component":"meta","property":"al:ios:app_store_id","content":"319908646"},{"component":"meta","property":"al:ios:app_name","content":"Domain Real Estate and Property"},{"component":"meta","property":"al:android:url","content":"domain://listing/17166328"},{"component":"meta","property":"al:android:package","content":"com.fairfax.domain"},{"component":"meta","property":"al:android:app_name","content":"Domain"},{"component":"meta","name":"twitter:card","content":"gallery"},{"component":"meta","name":"twitter:site","content":"@Domaincomau"},{"component":"meta","name":"twitter:title","content":"508/408 Lonsdale Street, Melbourne VIC 3000 - Apartment For Rent | Domain"},{"component":"meta","name":"twitter:description","content":"View this 1 bathroom rental apartment at 508/408 Lonsdale Street, Melbourne VIC 3000. Available from Friday, 10 February 2023. Contact agent for price."},{"component":"meta","name":"twitter:image0","content":"https://bucket-api.domain.com.au/v1/bucket/image/17166328_1_1_240818_111609-w2000-h1334"},{"component":"meta","name":"twitter:image1","content":"https://bucket-api.domain.com.au/v1/bucket/image/17166328_2_1_240818_111609-w2000-h1333"},{"component":"meta","name":"twitter:image2","content":"https://bucket-api.domain.com.au/v1/bucket/image/17166328_3_1_240818_111609-w2000-h1333"},{"component":"meta","name":"twitter:image3","content":"https://bucket-api.domain.com.au/v1/bucket/image/17166328_4_1_240818_111609-w2000-h1333"},{"component":"link","rel":"alternate","href":"android-app://com.fairfax.domain/https/www.domain.com.au/508-408-lonsdale-street-melbourne-vic-3000-17166328"},{"component":"link","rel":"alternate","href":"ios-app://319908646/domain.com.au/domainapp"},{"component":"meta","name":"product-type","content":"elitePp"}],"isArchived":false,"disableAds":false,"disableTracking":false,"isFromEu":false,"disableOptimize":false,"digitalData":{"page":{"pageInfo":{"agencyId":33232,"author":33232,"bookingSystem":"Inspect Real Estate","effectiveDate":"2024-08-19T09:16:09.123","isEmbeddedApp":false,"issueDate":"2024-08-19T09:16:09.120","pageId":17166328,"pageName":"property details - rent - 17166328 - 508/408 lonsdale street melbourne vic 3000","property":{"rentalMethod":"rent","address":"508/408 Lonsdale Street, Melbourne VIC 3000","adtype":"elitePp","agency":"Belle Property South Melbourne","agencyId":33232,"agentNames":"Cooper Cavallo","bathrooms":1,"bedrooms":0,"daysListed":15,"dateListed":"2024-08-19T09:16:10.000","inspectionsCount":0,"hasPhoto":true,"hasFloorplan":false,"hasDisplayPrice":true,"hasDescription":true,"descriptionHasEmail":false,"descriptionHasPhone":false,"hasSOI":false,"rentalSystem":"2Apply","virtual ...
#   </script>
#   <script src="/FAaDvpPjkxta/doppBBfwJv/k3/ii7NNtEOVimQOEaw/RVtxUzcaWgE/c3EA/QHxZRhw" type="text/javascript">
#   </script>
#  </body>
# </html>
